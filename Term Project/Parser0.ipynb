# %%
from multiprocessing import Pool

import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException

# %%
class Parser():
    
    # Open a Chrome broswer
    def __init__(self, startIndex, process):
        self.browser = webdriver.Chrome()
        
        self.numHit = 100
        self.numTotalData = 14479
        self.numPage = self.numTotalData // self.numHit + 1
        self.numData = startIndex
        self.index = self.numData % self.numHit
        self.pIndex = self.numData // self.numHit
        self.dict_nmr_data = dict()
        
        try:
            self.data = pd.read_pickle("nmrDB"+str(process)+".pkl")
        except FileNotFoundError:
            self.data = pd.DataFrame()
        
        try:
            self.exceptions = pd.read_pickle("exceptions"+str(process)+".pkl")
        except FileNotFoundError:
            self.exceptions = pd.DataFrame()
        
    # Parse every NMR data in SDBS
    def parseNMRData(self):
        self.navigateToMain()
        self.navigateToList(self.pIndex)
        while self.numData < self.numTotalData:
            self.pIndex = self.numData//self.numHit
            while self.pIndex < self.numPage:                
                if not self.parseList(self.pIndex):
                    self.navigateToList(self.pIndex)
                    break
                if not self.pIndex == self.numPage-1:
                    if self.navigateToNextList():
                        self.navigateToList(self.pIndex)
                        break
                self.pIndex += 1
            
        
    # Return True if the navigated page is asking for an agreement to disclaimer
    def checkDisclaimer(self):
        soup = BeautifulSoup(self.browser.page_source, 'html.parser')
        return "/sdbs/cgi-bin/cre_disclaimer.cgi?REQURL=/sdbs/cgi-bin/direct_frame_top.cgi&amp;amp;REFURL=" in soup.text
    
    # Navigate to the main page of SDBS
    def navigateToMain(self):
        self.browser.get("https://sdbs.db.aist.go.jp/sdbs/cgi-bin/direct_frame_top.cgi")
    
    # Click the agree button of the disclaimer page
    def agreeDisclaimer(self):
        self.browser.switch_to.default_content()
        self.browser.switch_to.frame("Down")
        agreeButton = self.browser.find_element_by_xpath("//input[@type='submit']")
        agreeButton.click()
        
    # Search for the 1H NMR data in the main page of SDBS
    def search1HNMR(self):
        self.browser.switch_to.default_content()
        self.browser.switch_to.frame("Down")
        hitComboBox = Select(self.browser.find_element_by_xpath("/html/body/form/center/table/tbody/tr[2]/td/select[1]"))
        hitComboBox.select_by_value(str(self.numHit))
        self.browser.find_element_by_xpath("/html/body/form/center/table/tbody/tr[1]/td[3]/table/tbody/tr[1]/td/table/tbody/tr[3]/td[1]/input").click()
        self.browser.find_element_by_xpath("/html/body/form/center/table/tbody/tr[2]/td/input[1]").click()
    
    # Parse the NMR data in a pIndex-th list page
    def parseList(self, pIndex):
        self.index = self.numData%self.numHit
        while self.index < self.numHit and self.numData < self.numTotalData:
            if not self.parseMol(self.index):
                return False
        self.index = 0
        return True
    
    # Navigate ot the pIndex-th list page from the disclaimer page
    def navigateToList(self, pIndex):
        self.navigateToMain()
        if self.checkDisclaimer():
            self.agreeDisclaimer()
        self.search1HNMR()
        
        numNav = 0 if pIndex < 30 else pIndex//15-1
        for i in range(numNav):
            self.browser.switch_to.default_content()
            self.browser.switch_to.frame("Down")
            if i == 0:
                navButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/a[29]")
            else:
                navButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/a[30]")
            navButton.click()
            if self.checkDisclaimer():
                return False
        if pIndex > 0 and pIndex < 30:
            listButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/a["+str(pIndex)+"]")
        elif pIndex >= self.numPage - (self.numPage % 15):
            listButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/a["+str(pIndex%15+21)+"]")
        elif pIndex >= 30 and pIndex < self.numPage - (self.numPage % 15):
            if pIndex%15 != 14:
                listButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/a["+str(16+pIndex%15)+"]")
            else:
                listButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/b/font")
        else:
            listButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/b/font")
        listButton.click()
        return self.checkDisclaimer()
    
    # Navigate to the next list page
    def navigateToNextList(self):
        self.browser.switch_to.default_content()
        self.browser.switch_to.frame("Down")
        if self.pIndex >= self.numPage - 15:
            nextListButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr[104]/td/a["+str(self.numPage-self.pIndex+2)+"]")
        elif self.pIndex < 15:
            nextListButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/a["+str(self.pIndex+1)+"]")
        else:
            nextListButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(self.numHit+4)+"]/td/a[16]")
        nextListButton.click()
        return self.checkDisclaimer()

    def parseMol(self, index):
        global startIndex
        
        self.navigateToDetail(index)
        self.parseMainPeak()
        self.navigateToPeak()
        self.parsePeak()
        self.index += 1
        self.numData += 1
        startIndex += 1
        self.navigateToResult()
        return True
                
    # Navigate to the detail page of index-th molecule in the list page
    def navigateToDetail(self, index):
        self.browser.switch_to.default_content()
        self.browser.switch_to.frame("Down")
        detailButton = self.browser.find_element_by_xpath("/html/body/center/table/tbody/tr["+str(3+index)+"]/td[9]/a")
        detailButton.click()
        return self.checkDisclaimer()
    
    def parseMainPeak(self):
        self.dict_nmr_data = dict()
        
        self.browser.switch_to.default_content()
        self.browser.switch_to.frame("Down")
        frame = self.browser.find_element_by_xpath("/html/frameset/frame[2]")
        self.browser.switch_to.frame(frame)
        
        mainPeaks = list()
        try:
            lines = self.browser.find_element_by_xpath("/html/body/table[2]/tbody/tr[2]/td/pre").text.splitlines()
        except:
            lines = self.browser.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[1]/pre").text.splitlines()
        for line in lines:
            elems = line.split()
            if len(elems) == 2:
                try:
                    float(elems[1])
                    mainPeaks.append(elems)
                except ValueError:
                    pass
        
        self.dict_nmr_data['mainPeaks'] = mainPeaks
    
    # Navigate to the peak data page in the detail page
    def navigateToPeak(self):
        self.browser.switch_to.default_content()
        self.browser.switch_to.frame("Down")
        frame = self.browser.find_element_by_xpath("/html/frameset/frame[2]")
        self.browser.switch_to.frame(frame)
        peakButton = self.browser.find_element_by_xpath("/html/body/form/input[5]")
        peakButton.click()
        return self.checkDisclaimer()
    
    # Parse data as a dictionary and append it to the self.data
    def parsePeak(self):        
        soup = BeautifulSoup(self.browser.page_source, 'html.parser')
        
        # Parse peak data
        peakData = soup.select('body > pre')[1].get_text().split()
        peaks = list()
        for i in range(0, len(peakData), 3):
            peaks.append(peakData[i:i+3])
        self.dict_nmr_data['peaks'] = peaks
        # Parse solvent data
        self.dict_nmr_data['solvent'] = soup.select('body > table > tbody > tr > td')[3].text[:-1]
        # Parse InChI code
        for candidate in soup.select('body > table > tbody > tr > td'):
            if candidate.text.strip()[:6] == "InChI=":
                self.dict_nmr_data['inchi'] = candidate.text.strip()
                break
        # Parse molecule name
        try:
            self.dict_nmr_data['name'] = soup.select('body > table > tbody > tr > td > font > b')[1].text[:-1]
        except IndexError:
            self.dict_nmr_data['name'] = "None"
            
        self.data = self.data.append(self.dict_nmr_data, ignore_index=True)
        self.data.to_pickle("nmrDB"+str(process)+".pkl")
        print("Parsed "+ str(self.numData) + "th molecule: " + self.dict_nmr_data['name'])
        
    def navigateToResult(self):
        self.browser.switch_to.default_content()
        self.browser.switch_to.frame("Down")
        frame = self.browser.find_element_by_xpath("/html/frameset/frame[1]")
        self.browser.switch_to.frame(frame)
        returnButton = self.browser.find_element_by_xpath("/html/body/a[2]")
        returnButton.click()
        return self.checkDisclaimer()

# %%
def parseNMRDB(info):
    startIndex, endIndex, process = info
    parser = Parser(startIndex, process)
    while startIndex < endIndex:
        try:
            parser.numData = startIndex
            parser.parseNMRData()
        except NoSuchElementException:
            parser.exceptions.append({"num": startIndex, "page": parser.pIndex, "index": parser.index}, ignore_index=True)
            parser.exceptions.to_pickle("exceptions"+str(process)+".pkl")
            print("Cannot parse " + str(startIndex) + "th molecule.")

            parser.index += 1
            parser.numData += 1
            startIndex += 1

# %%
infos = [[0, 4000, 0], [4000, 8000, 1], [8000, 12000, 2], [12000, 14479, 3]]

pool = Pool(processes=4)
pool.map(parseNMRDB, infos)
# Out:
# 0
# 0
# 0
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-9:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/connectionpool.py", line 377, in _make_request
#     httplib_response = conn.getresponse(buffering=True)
# Traceback (most recent call last):
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/connectionpool.py", line 377, in _make_request
#     httplib_response = conn.getresponse(buffering=True)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "<ipython-input-16-b6ca2e963030>", line 7, in parseNMRDB
#     parser.parseNMRData()
#   File "<ipython-input-15-06053c452d5f>", line 28, in parseNMRData
#     self.navigateToList(self.pIndex)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-15-06053c452d5f>", line 92, in navigateToList
#     navButton.click()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c6c37dcf39f5> in <module>
#       2
#       3 pool = Pool(processes=4)
# ----> 4 pool.map(parseNMRDB, infos)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda3/envs/pytorch/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/pytorch/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "<ipython-input-16-b6ca2e963030>", line 7, in parseNMRDB
#     parser.parseNMRData()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 376, in execute
#     return self._request(command_info[0], url, body=data)
#   File "<ipython-input-15-06053c452d5f>", line 32, in parseNMRData
#     if not self.parseList(self.pIndex):
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 399, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "<ipython-input-15-06053c452d5f>", line 72, in parseList
#     if not self.parseMol(self.index):
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/poolmanager.py", line 322, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "<ipython-input-15-06053c452d5f>", line 125, in parseMol
#     self.navigateToDetail(index)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "<ipython-input-15-06053c452d5f>", line 140, in navigateToDetail
#     detailButton.click()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
# KeyboardInterrupt
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 376, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 399, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/poolmanager.py", line 322, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/seungsukim/anaconda3/envs/pytorch/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt

# %%
df = pd.read_pickle("nmrDB.pkl")
df
# Out:
#                                                    inchi  \
# 0                                      InChI=1S/CH4/h1H4
# 1                                      InChI=1S/H2O/h1H2
# 2                                  InChI=1S/CH3.Li/h1H3;
# 3                                  InChI=1S/CHN/c1-2/h1H
# 4                                InChI=1S/CH2O/c1-2/h1H2
# 5                            InChI=1S/CH2O/c1-2/h1H2/i1D
# 6                                                    NaN
# 7                                                    NaN
# 8                             InChI=1S/CH4O/c1-2/h2H,1H3
# 9                                     InChI=1S/H4Si/h1H4
# 10                        InChI=1S/CH4O/c1-2/h2H,1H3/i2D
# 11                                InChI=1S/H4Si/h1H4/i1D
# 12                               InChI=1S/CH3F/c1-2/h1H3
# 13                                     InChI=1S/H2S/h1H2
# 14                                InChI=1S/H2S/h1H2/i/hD
# 15                    InChI=1S/CH4O/c1-2/h2H,1H3/i1D3,2D
# 16                      InChI=1S/C3H4/c1-2-3-1/h1-2H,3H2
# 17                            InChI=1S/C2H3N/c1-2-3/h1H3
# 18                         InChI=1S/C3H6/c1-2-3-1/h1-3H2
# 19                     InChI=1S/C2H5N/c1-2-3-1/h3H,1-2H2
# 20                              InChI=1S/C2HF/c1-2-3/h1H
# 21                                                   NaN
# 22                                                   NaN
# 23                         InChI=1S/C2H4O/c1-2-3/h2H,1H3
# 24                        InChI=1S/C2H4O/c1-2-3-1/h1-2H2
# 25                       InChI=1S/C2H3N/c1-2-3/h1H3/i1D3
# 26                       InChI=1S/C3H8/c1-3-2/h3H2,1-2H3
# 27                    InChI=1S/CH3NO/c2-1-3/h1H,(H2,2,3)
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 14198                                                NaN
# 14199                                                NaN
# 14200  InChI=1S/C48H40O4Si4/c1-9-25-41(26-10-1)53(42-...
# 14201  InChI=1S/C20H7BrCl12NO2/c21-5-1-3-4(2-6(5)34(3...
# 14202  InChI=1S/C51H98O6/c1-4-7-10-13-16-19-22-25-28-...
# 14203                                                NaN
# 14204  InChI=1S/C54H111BO3/c1-4-7-10-13-16-19-22-25-2...
# 14205                                                NaN
# 14206  InChI=1S/C20H4Br4Cl4O5.2Na/c21-5-1-3-17(9(23)1...
# 14207  InChI=1S/C20H8I4O5/c21-11-5-9-17(13(23)15(11)2...
# 14208  InChI=1S/C20H10Br4O10S2.2Na/c21-15-13-14(16(22...
# 14209  InChI=1S/C54H111O3P/c1-4-7-10-13-16-19-22-25-2...
# 14210  InChI=1S/C54H105O4P/c1-4-7-10-13-16-19-22-25-2...
# 14211                                                NaN
# 14212  InChI=1S/C57H104O6/c1-4-7-10-13-16-19-22-25-28...
# 14213  InChI=1S/C57H104O6/c1-4-7-10-13-16-19-22-25-28...
# 14214                                                NaN
# 14215  InChI=1S/C57H108O6/c1-4-7-10-13-16-19-22-25-28...
# 14216                                                NaN
# 14217  InChI=1S/C57H110O6/c1-4-7-10-13-16-19-22-25-28...
# 14218                                                NaN
# 14219                                                NaN
# 14220  InChI=1S/2C12H10N7O12.Ca/c2*20-14(21)5-1-7(16(...
# 14221                                                NaN
# 14222  InChI=1S/C47H48O12S4/c1-34-11-19-41(20-12-34)6...
# 14223                                                NaN
# 14224  InChI=1S/C63H122O6/c1-4-7-10-13-16-19-22-25-28...
# 14225                                                NaN
# 14226                                                NaN
# 14227  InChI=1S/C69H134O6/c1-4-7-10-13-16-19-22-25-28...
#
#                                                mainPeaks  \
# 0                                        [[D(A), 0.232]]
# 1                                            [[A, 1.58]]
# 2                                          [[A, -1.317]]
# 3                                         [[D(A), 4.10]]
# 4                                        [[D(A), 9.602]]
# 5                                        [[D(A), 9.573]]
# 6                                        [[D(A), 2.614]]
# 7                                        [[D(A), 2.613]]
# 8                                 [[A, 3.66], [B, 3.43]]
# 9                                         [[D(A), 3.20]]
# 10                                       [[D(A), 3.405]]
# 11                                        [[D(A), 3.29]]
# 12       [[D(A), 4.10], [D(X), -271.9], [J(A,X), 46.36]]
# 13                                       [[D(A), 0.717]]
# 14                                       [[D(A), 0.684]]
# 15                                [[A, 4.57], [B, 3.35]]
# 16          [[D(A), 7.06], [D(B), 0.93], [J(A,B), 1.75]]
# 17                                       [[D(A), 2.006]]
# 18                                       [[D(A), 0.198]]
# 19                          [[D(A), 1.36], [D(B), 0.88]]
# 20                        [[D(A), 1.45], [J(A,X), 15.3]]
# 21                              [[A, 7.820], [C, 1.922]]
# 22                                        [[D(A), 7.85]]
# 23         [[D(A), 9.789], [D(B), 2.206], [J(A,B), 2.9]]
# 24                                        [[D(A), 2.54]]
# 25                                          [[A, 1.940]]
# 26         [[D(A), 0.899], [D(B), 1.336], [J(A,B), 7.4]]
# 27     [[D(A), 7.475], [D(B), 7.213], [D(C), 8.206], ...
# 28                              [[B, 3.062], [C, 1.285]]
# 29                                       [[D(A), 2.737]]
# ...                                                  ...
# 14198  [[A, 16.4], [B, 8.141], [C, 7.846], [D, 7.533]...
# 14199                            [[A, 10.9], [B, 7.583]]
# 14200               [[A, 7.460], [B, 7.319], [C, 7.160]]
# 14201   [[A, 8.316], [B, 8.163], [C, 3.982], [D, 3.569]]
# 14202  [[B, 4.02], [D, 2.32], [E, 1.62], [F, 1.26], [...
# 14203  [[A, 8.575], [B, 8.234], [C, 8.10], [D, 8.07],...
# 14204     [[A, 3.629], [B, 1.56], [D, 1.26], [E, 0.880]]
# 14205                [[A, 8.598], [B, 8.33], [C, 7.549]]
# 14206                                       [[A, 7.173]]
# 14207  [[A, 10.3], [B, 8.22], [B, 8.05], [E, 7.47], [...
# 14208                  [[A, 7.73], [B, 7.23], [C, 6.87]]
# 14209  [[A, 3.637], [B, 1.565], [C, 1.31], [D, 1.26],...
# 14210    [[B, 4.020], [C, 2.01], [D, 1.667], [F, 0.879]]
# 14211  [[A, 5.35], [B, 5.27], [E, 2.769], [F, 2.315],...
# 14212       [[D, 2.32], [E, 2.01], [F, 1.61], [J, 0.89]]
# 14213  [[A, 5.38], [B, 5.266], [E, 2.309], [F, 1.960]...
# 14214  [[A, 5.35], [B, 5.268], [E, 2.311], [F, 2.009]...
# 14215  [[A, 5.34], [B, 5.267], [E, 2.311], [F, 2.010]...
# 14216  [[D(A), 8.048], [D(B), 7.937], [D(C), 7.738], ...
# 14217  [[A, 5.268], [D, 2.310], [E, 1.606], [F, 1.29]...
# 14218  [[A, 7.83], [B, 7.80], [C, 7.588], [D, 7.525],...
# 14219  [[A, 8.045], [B, 7.985], [C, 7.148], [D, 7.049...
# 14220                                    [[D(A), 8.795]]
# 14221               [[A, 7.672], [B, 7.539], [C, 7.459]]
# 14222  [[B, 7.723], [F, 7.188], [G, 6.961], [L, 3.635...
# 14223                     [[D(A), 6.000], [D(B), 2.168]]
# 14224  [[A, 5.270], [D, 2.311], [E, 1.609], [F, 1.28]...
# 14225               [[A, 7.232], [B, 7.153], [C, 1.680]]
# 14226  [[A, 5.347], [B, 5.267], [E, 2.310], [F, 2.011...
# 14227  [[A, 5.255], [D, 2.302], [E, 1.60], [F, 1.29],...
#
#                                                     name  \
# 0                                                methane
# 1                                                   None
# 2                                          methyllithium
# 3                                       hydrogen cyanide
# 4                                           formaldehyde
# 5                                         formaldehyde-d
# 6                              methylamine hydrochloride
# 7                                    methylamine sulfate
# 8                                               methanol
# 9                                                 silane
# 10                                            methanol-d
# 11                                              silane-d
# 12                                         fluoromethane
# 13                                      hydrogen sulfide
# 14                                    hydrogen-d sulfide
# 15                                           methanol-d4
# 16                                          cyclopropene
# 17                                          acetonitrile
# 18                                          cyclopropane
# 19                                             aziridine
# 20                                       fluoroacetylene
# 21                                   formamidine acetate
# 22                             formamidine hydrochloride
# 23                                          acetaldehyde
# 24                                        ethylene oxide
# 25                                       acetonitrile-d3
# 26                                               propane
# 27                                             formamide
# 28                               ethylamine hydrobromide
# 29                           dimethylamine hydrochloride
# ...                                                  ...
# 14198  4,5-dihydroxy-3,6-bis(o-sulfophenylazo)-2,7-na...
# 14199  2',4',5',7'-tetrabromo-4,5,6,7-tetrachlorofluo...
# 14200                       octaphenylcyclotetrasiloxane
# 14201  2-bromo-3-nitronaphthalene-bis(hexachlorocyclo...
# 14202                   propane-1,2,3-triyl tripalmitate
# 14203                             nitro blue tetrazolium
# 14204                                trioctadecyl borate
# 14205                                 nitrosulfonazo III
# 14206                                         phloxine b
# 14207                   2',4',5',7'-tetraiodofluorescein
# 14208                         sulfobromophthalein sodium
# 14209                             trioctadecyl phosphite
# 14210                  tris(cis-9-octadecenyl) phosphate
# 14211  1,2,3-propanetriyl tris(cis,cis-9,12-octadecad...
# 14212                       1,2,3-propanetriyl trioleate
# 14213     1,2,3-propanetriyl tris(trans-9-octadecenoate)
# 14214                   glycerol 1-oleate 2,3-distearate
# 14215                   glycerol 2-oleate 1,3-distearate
# 14216                                 bromosulfonazo III
# 14217                     1,2,3-propanetriyl tristearate
# 14218  3',3'',5',5''-tetraiodophenolphthalein dipotas...
# 14219  (3',3'-dimethyl-6-nitro-1'-octadecyl-1',3'-dih...
# 14220                         dipicrylamine calcium salt
# 14221           chlorotris(triphenylphosphine)rhodium(I)
# 14222  8,8,10,10-tetrakis(p-tolylsulfonyloxymethyl)-8...
# 14223  bis(tris(acetylacetonato)titanium(IV)) hexachl...
# 14224                   1,2,3-propanetriyl triicosanoate
# 14225  carbonic acid tetramol. cyclic isopropylidened...
# 14226        1,2,3-propanetriyl tris(cis-13-docosenoate)
# 14227                  1,2,3-propanetriyl tridocosanoate
#
#                                                    peaks  \
# 0                                 [[69.60, 0.232, 1000]]
# 1                                [[631.05, 1.579, 1000]]
# 2      [[-526.24, -1.316, 1000], [-534.29, -1.336, 29...
# 3                               [[1230.00, 4.100, 1000]]
# 4                               [[2880.60, 9.602, 1000]]
# 5                               [[2871.90, 9.573, 1000]]
# 6                                [[784.20, 2.614, 1000]]
# 7                                [[783.90, 2.613, 1000]]
# 8      [[336.81, 3.761, 36], [331.25, 3.699, 135], [3...
# 9                                [[960.00, 3.200, 1000]]
# 10                              [[1021.50, 3.405, 1000]]
# 11                               [[987.00, 3.290, 1000]]
# 12      [[1253.18, 4.177, 1000], [1206.82, 4.023, 1000]]
# 13                               [[215.10, 0.717, 1000]]
# 14                               [[205.20, 0.684, 1000]]
# 15     [[413.56, 4.618, 63], [409.75, 4.576, 867], [4...
# 16     [[2118.90, 7.063, 995], [2117.19, 7.057, 997],...
# 17                               [[601.80, 2.006, 1000]]
# 18                                [[59.40, 0.198, 1000]]
# 19         [[408.00, 1.360, 1000], [264.00, 0.880, 250]]
# 20        [[442.65, 1.475, 1000], [427.35, 1.424, 1000]]
# 21         [[700.50, 7.822, 181], [172.25, 1.924, 1000]]
# 22                              [[2355.00, 7.850, 1000]]
# 23     [[2941.02, 9.803, 87], [2938.14, 9.794, 251], ...
# 24                               [[762.00, 2.540, 1000]]
# 25     [[782.96, 1.960, 24], [780.52, 1.954, 344], [7...
# 26     [[416.39, 1.388, 37], [415.60, 1.385, 34], [40...
# 27     [[2469.80, 8.233, 600], [2467.62, 8.225, 611],...
# 28     [[285.94, 3.193, 270], [285.44, 3.188, 233], [...
# 29                               [[821.10, 2.737, 1000]]
# ...                                                  ...
# 14198  [[6577.88, 16.460, 35], [6567.38, 16.433, 179]...
# 14199    [[4364.49, 10.921, 21], [3030.67, 7.584, 1000]]
# 14200  [[2986.69, 7.474, 644], [2985.23, 7.470, 827],...
# 14201  [[3323.73, 8.317, 987], [3267.33, 8.176, 41], ...
# 14202  [[207.25, 2.315, 28], [199.94, 2.233, 21], [19...
# 14203  [[3436.65, 8.600, 53], [3434.57, 8.594, 88], [...
# 14204  [[1450.56, 3.630, 22], [528.81, 1.324, 34], [5...
# 14205  [[3437.62, 8.602, 520], [3435.91, 8.598, 490],...
# 14206                           [[2866.82, 7.174, 1000]]
# 14207  [[4110.71, 10.286, 59], [3290.25, 8.233, 129],...
# 14208  [[693.81, 7.747, 1000], [691.50, 7.722, 966], ...
# 14209  [[1460.45, 3.655, 72], [1453.74, 3.638, 147], ...
# 14210  [[2149.66, 5.379, 32], [2141.11, 5.358, 93], [...
# 14211  [[2147.71, 5.374, 123], [2146.48, 5.371, 166],...
# 14212  [[482.88, 5.392, 65], [481.19, 5.373, 44], [47...
# 14213  [[2154.79, 5.392, 109], [2152.22, 5.386, 123],...
# 14214  [[1665.77, 4.169, 30], [1659.79, 4.154, 30], [...
# 14215  [[1713.62, 4.288, 32], [1665.89, 4.169, 30], [...
# 14216  [[2419.02, 8.063, 210], [2410.23, 8.034, 254],...
# 14217  [[1713.38, 4.288, 23], [1709.11, 4.277, 21], [...
# 14218  [[3132.45, 7.838, 92], [3129.52, 7.831, 23], [...
# 14219  [[2938.23, 7.353, 258], [1949.71, 4.879, 68], ...
# 14220                           [[2638.50, 8.795, 1000]]
# 14221  [[3077.27, 7.700, 550], [3075.93, 7.697, 726],...
# 14222  [[3142.21, 7.863, 63], [3140.26, 7.858, 365], ...
# 14223     [[1799.98, 6.000, 667], [650.41, 2.168, 1000]]
# 14224  [[930.42, 2.329, 31], [925.17, 2.315, 34], [92...
# 14225  [[2898.80, 7.254, 84], [2895.87, 7.247, 460], ...
# 14226  [[2141.85, 5.360, 87], [2137.08, 5.348, 188], ...
# 14227  [[927.00, 2.320, 24], [921.75, 2.307, 26], [91...
#
#                            solvent
# 0                   10 wt% in CCl4
# 1           0.000 g : 0.5 ml CDCl3
# 2      0.05 ml : 0.5 ml benzene-d6
# 3                             neat
# 4                       5 % in TMS
# 5                       5 % in TMS
# 6             0.042 g : 0.5 ml D2O
# 7             0.044 g : 0.5 ml D2O
# 8           0.05 ml : 0.5 ml CDCl3
# 9                   in cyclohexane
# 10           0.04 ml : 0.5 mlCDCl3
# 11          80 vol% in TMS at -50C
# 12           5 vol% in cyclohexane
# 13                          in CS2
# 14                          in CS2
# 15               50  VOL% in CDCl3
# 16                    neat at -60C
# 17          0.04 ml : 0.5 ml CDCl3
# 18                            neat
# 19                            neat
# 20                         in CCl4
# 21            0.036 g : 0.5 ml D2O
# 22            0.046 g : 0.5 ml D2O
# 23          0.04 ml : 0.5 ml CDCl3
# 24                            neat
# 25                            neat
# 26                    10 % in CCl4
# 27                            neat
# 28            0.038 g : 0.5 ml D2O
# 29            0.042 g : 0.5 ml D2O
# ...                            ...
# 14198     0.038 g : 0.5 ml DMSO-d6
# 14199     0.042 g : 0.5 ml DMSO-d6
# 14200       0.040 g : 0.5 ml CDCl3
# 14201       0.038 g : 0.5 ml CDCl3
# 14202       0.043 g : 0.5 ml CDCl3
# 14203         0.012 g : 0.5 ml D2O
# 14204       0.039 g : 0.5 ml CDCl3
# 14205     0.036 g : 0.5 ml DMSO-d6
# 14206     0.038 g : 0.5 ml DMSO-d6
# 14207     0.030 g : 0.5 ml DMSO-d6
# 14208         0.045 g : 0.5 ml D2O
# 14209       0.040 g : 0.5 ml CDCl3
# 14210       0.05 ml : 0.5 ml CDCl3
# 14211       0.05 ml : 0.5 ml CDCl3
# 14212       0.04 ml : 0.5 ml CDCl3
# 14213       0.031 g : 0.5 ml CDCl3
# 14214       0.032 g : 0.5 ml CDCl3
# 14215       0.036 g : 0.5 ml CDCl3
# 14216     0.033 g : 0.5 ml DMSO-d6
# 14217       0.030 g : 0.5 ml CDCl3
# 14218     0.035 g : 0.5 ml DMSO-d6
# 14219       0.003 g : 0.5 ml CDCl3
# 14220     0.048 g : 0.5 ml DMSO-d6
# 14221     0.030 g : 0.5 ml DMSO-d6
# 14222               5 wt% in CDCl3
# 14223       0.049 g : 0.5 ml CDCl3
# 14224       0.032 g : 0.5 ml CDCl3
# 14225       0.014 g : 0.5 ml CDCl3
# 14226       0.030 g : 0.5 ml CDCl3
# 14227       0.029 g : 0.5 ml CDCl3
#
# [14228 rows x 5 columns]

# %%
inchi_list = list()
for name, value in df['inchi'].iteritems():
    if type(value) != type(0.0):
        if not value in inchi_list:
            inchi_list.append(value)
        
print(len(inchi_list))
# Out:
# 11085

# %%
2092

# %%
print(14228-2092)
# Out:
# 12136

# %%
df_exc = pd.read_pickle("exceptions.pkl")
df_exc
# Out:
# Empty DataFrame
# Columns: []
# Index: []
