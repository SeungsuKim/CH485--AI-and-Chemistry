# %%
import numpy as np
import tensorflow as tf
from utils import read_data
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from scipy import stats
from sklearn.metrics import accuracy_score, roc_auc_score
import seaborn as sns

tox_types = ['nr-ahr', 'nr-ar-lbd', 'nr-ar', 
             'nr-aromatase', 'nr-er-lbd', 'nr-er', 
             'nr-ppar-gamma', 'sr-are', 'sr-atad5', 
             'sr-hse', 'sr-mmp', 'sr-p53']

# %%
num_layer = 2
hidden_dim = 256
init_lr = 0.001
drop_rate = 0
reg_scale = 0.1

# %%
tox_type = 'nr-ahr'
smiles, label = read_data('tox21/' + tox_type)

smiles.shape, label.shape
# Out:
# ((8169,), (8169,))

# %%
mols = np.array([Chem.MolFromSmiles(smile) for smile in smiles])
fps_total = []
labels_total = []
for i in range(len(mols)):
    try:
        fp = AllChem.GetMorganFingerprintAsBitVect(mols[i], 2)
        arr = np.zeros((1,))
        DataStructs.ConvertToNumpyArray(fp,arr)
        fps_total.append(arr)
        labels_total.append(label[i])
    except:
        pass

fps_total = np.asarray(fps_total)
labels_total = np.asarray(labels_total)

fps_total.shape, labels_total.shape
# Out:
# ((8162, 2048), (8162,))

# %%
num_total = fps_total.shape[0]
num_train = int(num_total*0.7)
num_validation = int(num_total*0.15)
num_test = int(num_total*0.15)

labels = labels_total
labels_total = np.zeros((num_total, 2))
for i in range(num_total):
    labels_total[i][labels[i]] = 1

fps_train = fps_total[:num_train]
labels_train = labels_total[:num_train]
fps_validation = fps_total[num_train:num_train+num_validation]
labels_validation = labels_total[num_train:num_train+num_validation]
fps_test = fps_total[num_total-num_test:]
labels_test = labels_total[num_total-num_test:]

# %%
X = tf.placeholder(tf.float64, shape=[None, 2048])
Y = tf.placeholder(tf.float64, shape=[None, 2])
is_training = tf.placeholder(tf.bool, shape=())

h = X
regularizer = tf.contrib.layers.l2_regularizer(scale=reg_scale)

for i in range(num_layer):
    h = tf.layers.dense(h,
                        units=hidden_dim,
                        use_bias=True,
                        activation=tf.nn.relu,
                        kernel_initializer=tf.contrib.layers.xavier_initializer(),
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer)
    h = tf.layers.dropout(h,
                          rate=drop_rate,
                          training=is_training)
'''
h = tf.layers.dense(h,
                    units=hidden_dim,
                    use_bias=True,
                    activation=tf.nn.sigmoid,
                    kernel_initializer=tf.contrib.layers.xavier_initializer(),
                    kernel_regularizer=regularizer,
                    bias_regularizer=regularizer)
'''
Y_pred = tf.layers.dense(h,
                         units=2,
                         use_bias=True,
                         activation=tf.nn.sigmoid,
                         kernel_initializer=tf.contrib.layers.xavier_initializer(),
                         kernel_regularizer=regularizer,
                         bias_regularizer=regularizer)

# %%
Y_pred.shape, tf.layers.flatten(Y_pred).shape
# Out:
# (TensorShape([Dimension(None), Dimension(2)]),
#  TensorShape([Dimension(None), Dimension(2)]))

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=Y_pred, labels=Y)
loss = cross_entropy
# Out:
# WARNING:tensorflow:From <ipython-input-8-72c66c4aedb2>:1: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
lr = tf.Variable(0.0, trainable = False)
opt = tf.train.AdamOptimizer(lr).minimize(loss)
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %%
batch_size = 100
epoch_size = 100
decay_rate = 0.95
batch_train = int(num_train/batch_size)
batch_validation = int(num_validation/batch_size)
batch_test = int(num_test/batch_size)

for t in range(epoch_size):
    pred_train = []
    sess.run(tf.assign(lr, init_lr*(decay_rate**t)))
    for i in range(batch_train):
        X_batch = fps_train[i*batch_size:(i+1)*batch_size]
        Y_batch = labels_train[i*batch_size:(i+1)*batch_size]
        _opt, _Y, _loss = sess.run([opt, Y_pred, loss], feed_dict = {X: X_batch, Y: Y_batch, is_training: True})
        pred_train.append(_Y)
        print("Epoch: ", t, "\t batch: ", i, "\t Training")
    pred_train = np.concatenate(pred_train, axis=0)
    
    pred_validation = []
    for i in range(batch_validation):
        X_batch = fps_validation[i*batch_size:(i+1)*batch_size]
        Y_batch = labels_validation[i*batch_size:(i+1)*batch_size]
        _Y, _loss = sess.run([Y_pred, loss], feed_dict={X: X_batch, Y: Y_batch, is_training: False})
        pred_validation.append(_Y)
        print("Epoch: ", t, "\tbatch: ", i, "\tValidating")
    pred_validation = np.concatenate(pred_validation, axis=0)
# Out:
# Epoch:  0 	 batch:  0 	 Training
# Epoch:  0 	 batch:  1 	 Training
# Epoch:  0 	 batch:  2 	 Training
# Epoch:  0 	 batch:  3 	 Training
# Epoch:  0 	 batch:  4 	 Training
# Epoch:  0 	 batch:  5 	 Training
# Epoch:  0 	 batch:  6 	 Training
# Epoch:  0 	 batch:  7 	 Training
# Epoch:  0 	 batch:  8 	 Training
# Epoch:  0 	 batch:  9 	 Training
# Epoch:  0 	 batch:  10 	 Training
# Epoch:  0 	 batch:  11 	 Training
# Epoch:  0 	 batch:  12 	 Training
# Epoch:  0 	 batch:  13 	 Training
# Epoch:  0 	 batch:  14 	 Training
# Epoch:  0 	 batch:  15 	 Training
# Epoch:  0 	 batch:  16 	 Training
# Epoch:  0 	 batch:  17 	 Training
# Epoch:  0 	 batch:  18 	 Training
# Epoch:  0 	 batch:  19 	 Training
# Epoch:  0 	 batch:  20 	 Training
# Epoch:  0 	 batch:  21 	 Training
# Epoch:  0 	 batch:  22 	 Training
# Epoch:  0 	 batch:  23 	 Training
# Epoch:  0 	 batch:  24 	 Training
# Epoch:  0 	 batch:  25 	 Training
# Epoch:  0 	 batch:  26 	 Training
# Epoch:  0 	 batch:  27 	 Training
# Epoch:  0 	 batch:  28 	 Training
# Epoch:  0 	 batch:  29 	 Training
# Epoch:  0 	 batch:  30 	 Training
# Epoch:  0 	 batch:  31 	 Training
# Epoch:  0 	 batch:  32 	 Training
# Epoch:  0 	 batch:  33 	 Training
# Epoch:  0 	 batch:  34 	 Training
# Epoch:  0 	 batch:  35 	 Training
# Epoch:  0 	 batch:  36 	 Training
# Epoch:  0 	 batch:  37 	 Training
# Epoch:  0 	 batch:  38 	 Training
# Epoch:  0 	 batch:  39 	 Training
# Epoch:  0 	 batch:  40 	 Training
# Epoch:  0 	 batch:  41 	 Training
# Epoch:  0 	 batch:  42 	 Training
# Epoch:  0 	 batch:  43 	 Training
# Epoch:  0 	 batch:  44 	 Training
# Epoch:  0 	 batch:  45 	 Training
# Epoch:  0 	 batch:  46 	 Training
# Epoch:  0 	 batch:  47 	 Training
# Epoch:  0 	 batch:  48 	 Training
# Epoch:  0 	 batch:  49 	 Training
# Epoch:  0 	 batch:  50 	 Training
# Epoch:  0 	 batch:  51 	 Training
# Epoch:  0 	 batch:  52 	 Training
# Epoch:  0 	 batch:  53 	 Training
# Epoch:  0 	 batch:  54 	 Training
# Epoch:  0 	 batch:  55 	 Training
# Epoch:  0 	 batch:  56 	 Training
# Epoch:  0 	batch:  0 	Validating
# Epoch:  0 	batch:  1 	Validating
# Epoch:  0 	batch:  2 	Validating
# Epoch:  0 	batch:  3 	Validating
# Epoch:  0 	batch:  4 	Validating
# Epoch:  0 	batch:  5 	Validating
# Epoch:  0 	batch:  6 	Validating
# Epoch:  0 	batch:  7 	Validating
# Epoch:  0 	batch:  8 	Validating
# Epoch:  0 	batch:  9 	Validating
# Epoch:  0 	batch:  10 	Validating
# Epoch:  0 	batch:  11 	Validating
# Epoch:  1 	 batch:  0 	 Training
# Epoch:  1 	 batch:  1 	 Training
# Epoch:  1 	 batch:  2 	 Training
# Epoch:  1 	 batch:  3 	 Training
# Epoch:  1 	 batch:  4 	 Training
# Epoch:  1 	 batch:  5 	 Training
# Epoch:  1 	 batch:  6 	 Training
# Epoch:  1 	 batch:  7 	 Training
# Epoch:  1 	 batch:  8 	 Training
# Epoch:  1 	 batch:  9 	 Training
# Epoch:  1 	 batch:  10 	 Training
# Epoch:  1 	 batch:  11 	 Training
# Epoch:  1 	 batch:  12 	 Training
# Epoch:  1 	 batch:  13 	 Training
# Epoch:  1 	 batch:  14 	 Training
# Epoch:  1 	 batch:  15 	 Training
# Epoch:  1 	 batch:  16 	 Training
# Epoch:  1 	 batch:  17 	 Training
# Epoch:  1 	 batch:  18 	 Training
# Epoch:  1 	 batch:  19 	 Training
# Epoch:  1 	 batch:  20 	 Training
# Epoch:  1 	 batch:  21 	 Training
# Epoch:  1 	 batch:  22 	 Training
# Epoch:  1 	 batch:  23 	 Training
# Epoch:  1 	 batch:  24 	 Training
# Epoch:  1 	 batch:  25 	 Training
# Epoch:  1 	 batch:  26 	 Training
# Epoch:  1 	 batch:  27 	 Training
# Epoch:  1 	 batch:  28 	 Training
# Epoch:  1 	 batch:  29 	 Training
# Epoch:  1 	 batch:  30 	 Training
# Epoch:  1 	 batch:  31 	 Training
# Epoch:  1 	 batch:  32 	 Training
# Epoch:  1 	 batch:  33 	 Training
# Epoch:  1 	 batch:  34 	 Training
# Epoch:  1 	 batch:  35 	 Training
# Epoch:  1 	 batch:  36 	 Training
# Epoch:  1 	 batch:  37 	 Training
# Epoch:  1 	 batch:  38 	 Training
# Epoch:  1 	 batch:  39 	 Training
# Epoch:  1 	 batch:  40 	 Training
# Epoch:  1 	 batch:  41 	 Training
# Epoch:  1 	 batch:  42 	 Training
# Epoch:  1 	 batch:  43 	 Training
# Epoch:  1 	 batch:  44 	 Training
# Epoch:  1 	 batch:  45 	 Training
# Epoch:  1 	 batch:  46 	 Training
# Epoch:  1 	 batch:  47 	 Training
# Epoch:  1 	 batch:  48 	 Training
# Epoch:  1 	 batch:  49 	 Training
# Epoch:  1 	 batch:  50 	 Training
# Epoch:  1 	 batch:  51 	 Training
# Epoch:  1 	 batch:  52 	 Training
# Epoch:  1 	 batch:  53 	 Training
# Epoch:  1 	 batch:  54 	 Training
# Epoch:  1 	 batch:  55 	 Training
# Epoch:  1 	 batch:  56 	 Training
# Epoch:  1 	batch:  0 	Validating
# Epoch:  1 	batch:  1 	Validating
# Epoch:  1 	batch:  2 	Validating
# Epoch:  1 	batch:  3 	Validating
# Epoch:  1 	batch:  4 	Validating
# Epoch:  1 	batch:  5 	Validating
# Epoch:  1 	batch:  6 	Validating
# Epoch:  1 	batch:  7 	Validating
# Epoch:  1 	batch:  8 	Validating
# Epoch:  1 	batch:  9 	Validating
# Epoch:  1 	batch:  10 	Validating
# Epoch:  1 	batch:  11 	Validating
# Epoch:  2 	 batch:  0 	 Training
# Epoch:  2 	 batch:  1 	 Training
# Epoch:  2 	 batch:  2 	 Training
# Epoch:  2 	 batch:  3 	 Training
# Epoch:  2 	 batch:  4 	 Training
# Epoch:  2 	 batch:  5 	 Training
# Epoch:  2 	 batch:  6 	 Training
# Epoch:  2 	 batch:  7 	 Training
# Epoch:  2 	 batch:  8 	 Training
# Epoch:  2 	 batch:  9 	 Training
# Epoch:  2 	 batch:  10 	 Training
# Epoch:  2 	 batch:  11 	 Training
# Epoch:  2 	 batch:  12 	 Training
# Epoch:  2 	 batch:  13 	 Training
# Epoch:  2 	 batch:  14 	 Training
# Epoch:  2 	 batch:  15 	 Training
# Epoch:  2 	 batch:  16 	 Training
# Epoch:  2 	 batch:  17 	 Training
# Epoch:  2 	 batch:  18 	 Training
# Epoch:  2 	 batch:  19 	 Training
# Epoch:  2 	 batch:  20 	 Training
# Epoch:  2 	 batch:  21 	 Training
# Epoch:  2 	 batch:  22 	 Training
# Epoch:  2 	 batch:  23 	 Training
# Epoch:  2 	 batch:  24 	 Training
# Epoch:  2 	 batch:  25 	 Training
# Epoch:  2 	 batch:  26 	 Training
# Epoch:  2 	 batch:  27 	 Training
# Epoch:  2 	 batch:  28 	 Training
# Epoch:  2 	 batch:  29 	 Training
# Epoch:  2 	 batch:  30 	 Training
# Epoch:  2 	 batch:  31 	 Training
# Epoch:  2 	 batch:  32 	 Training
# Epoch:  2 	 batch:  33 	 Training
# Epoch:  2 	 batch:  34 	 Training
# Epoch:  2 	 batch:  35 	 Training
# Epoch:  2 	 batch:  36 	 Training
# Epoch:  2 	 batch:  37 	 Training
# Epoch:  2 	 batch:  38 	 Training
# Epoch:  2 	 batch:  39 	 Training
# Epoch:  2 	 batch:  40 	 Training
# Epoch:  2 	 batch:  41 	 Training
# Epoch:  2 	 batch:  42 	 Training
# Epoch:  2 	 batch:  43 	 Training
# Epoch:  2 	 batch:  44 	 Training
# Epoch:  2 	 batch:  45 	 Training
# Epoch:  2 	 batch:  46 	 Training
# Epoch:  2 	 batch:  47 	 Training
# Epoch:  2 	 batch:  48 	 Training
# Epoch:  2 	 batch:  49 	 Training
# Epoch:  2 	 batch:  50 	 Training
# Epoch:  2 	 batch:  51 	 Training
# Epoch:  2 	 batch:  52 	 Training
# Epoch:  2 	 batch:  53 	 Training
# Epoch:  2 	 batch:  54 	 Training
# Epoch:  2 	 batch:  55 	 Training
# Epoch:  2 	 batch:  56 	 Training
# Epoch:  2 	batch:  0 	Validating
# Epoch:  2 	batch:  1 	Validating
# Epoch:  2 	batch:  2 	Validating
# Epoch:  2 	batch:  3 	Validating
# Epoch:  2 	batch:  4 	Validating
# Epoch:  2 	batch:  5 	Validating
# Epoch:  2 	batch:  6 	Validating
# Epoch:  2 	batch:  7 	Validating
# Epoch:  2 	batch:  8 	Validating
# Epoch:  2 	batch:  9 	Validating
# Epoch:  2 	batch:  10 	Validating
# Epoch:  2 	batch:  11 	Validating
# Epoch:  3 	 batch:  0 	 Training
# Epoch:  3 	 batch:  1 	 Training
# Epoch:  3 	 batch:  2 	 Training
# Epoch:  3 	 batch:  3 	 Training
# Epoch:  3 	 batch:  4 	 Training
# Epoch:  3 	 batch:  5 	 Training
# Epoch:  3 	 batch:  6 	 Training
# Epoch:  3 	 batch:  7 	 Training
# Epoch:  3 	 batch:  8 	 Training
# Epoch:  3 	 batch:  9 	 Training
# Epoch:  3 	 batch:  10 	 Training
# Epoch:  3 	 batch:  11 	 Training
# Epoch:  3 	 batch:  12 	 Training
# Epoch:  3 	 batch:  13 	 Training
# Epoch:  3 	 batch:  14 	 Training
# Epoch:  3 	 batch:  15 	 Training
# Epoch:  3 	 batch:  16 	 Training
# Epoch:  3 	 batch:  17 	 Training
# Epoch:  3 	 batch:  18 	 Training
# Epoch:  3 	 batch:  19 	 Training
# Epoch:  3 	 batch:  20 	 Training
# Epoch:  3 	 batch:  21 	 Training
# Epoch:  3 	 batch:  22 	 Training
# Epoch:  3 	 batch:  23 	 Training
# Epoch:  3 	 batch:  24 	 Training
# Epoch:  3 	 batch:  25 	 Training
# Epoch:  3 	 batch:  26 	 Training
# Epoch:  3 	 batch:  27 	 Training
# Epoch:  3 	 batch:  28 	 Training
# Epoch:  3 	 batch:  29 	 Training
# Epoch:  3 	 batch:  30 	 Training
# Epoch:  3 	 batch:  31 	 Training
# Epoch:  3 	 batch:  32 	 Training
# Epoch:  3 	 batch:  33 	 Training
# Epoch:  3 	 batch:  34 	 Training
# Epoch:  3 	 batch:  35 	 Training
# Epoch:  3 	 batch:  36 	 Training
# Epoch:  3 	 batch:  37 	 Training
# Epoch:  3 	 batch:  38 	 Training
# Epoch:  3 	 batch:  39 	 Training
# Epoch:  3 	 batch:  40 	 Training
# Epoch:  3 	 batch:  41 	 Training
# Epoch:  3 	 batch:  42 	 Training
# Epoch:  3 	 batch:  43 	 Training
# Epoch:  3 	 batch:  44 	 Training
# Epoch:  3 	 batch:  45 	 Training
# Epoch:  3 	 batch:  46 	 Training
# Epoch:  3 	 batch:  47 	 Training
# Epoch:  3 	 batch:  48 	 Training
# Epoch:  3 	 batch:  49 	 Training
# Epoch:  3 	 batch:  50 	 Training
# Epoch:  3 	 batch:  51 	 Training
# Epoch:  3 	 batch:  52 	 Training
# Epoch:  3 	 batch:  53 	 Training
# Epoch:  3 	 batch:  54 	 Training
# Epoch:  3 	 batch:  55 	 Training
# Epoch:  3 	 batch:  56 	 Training
# Epoch:  3 	batch:  0 	Validating
# Epoch:  3 	batch:  1 	Validating
# Epoch:  3 	batch:  2 	Validating
# Epoch:  3 	batch:  3 	Validating
# Epoch:  3 	batch:  4 	Validating
# Epoch:  3 	batch:  5 	Validating
# Epoch:  3 	batch:  6 	Validating
# Epoch:  3 	batch:  7 	Validating
# Epoch:  3 	batch:  8 	Validating
# Epoch:  3 	batch:  9 	Validating
# Epoch:  3 	batch:  10 	Validating
# Epoch:  3 	batch:  11 	Validating
# Epoch:  4 	 batch:  0 	 Training
# Epoch:  4 	 batch:  1 	 Training
# Epoch:  4 	 batch:  2 	 Training
# Epoch:  4 	 batch:  3 	 Training
# Epoch:  4 	 batch:  4 	 Training
# Epoch:  4 	 batch:  5 	 Training
# Epoch:  4 	 batch:  6 	 Training
# Epoch:  4 	 batch:  7 	 Training
# Epoch:  4 	 batch:  8 	 Training
# Epoch:  4 	 batch:  9 	 Training
# Epoch:  4 	 batch:  10 	 Training
# Epoch:  4 	 batch:  11 	 Training
# Epoch:  4 	 batch:  12 	 Training
# Epoch:  4 	 batch:  13 	 Training
# Epoch:  4 	 batch:  14 	 Training
# Epoch:  4 	 batch:  15 	 Training
# Epoch:  4 	 batch:  16 	 Training
# Epoch:  4 	 batch:  17 	 Training
# Epoch:  4 	 batch:  18 	 Training
# Epoch:  4 	 batch:  19 	 Training
# Epoch:  4 	 batch:  20 	 Training
# Epoch:  4 	 batch:  21 	 Training
# Epoch:  4 	 batch:  22 	 Training
# Epoch:  4 	 batch:  23 	 Training
# Epoch:  4 	 batch:  24 	 Training
# Epoch:  4 	 batch:  25 	 Training
# Epoch:  4 	 batch:  26 	 Training
# Epoch:  4 	 batch:  27 	 Training
# Epoch:  4 	 batch:  28 	 Training
# Epoch:  4 	 batch:  29 	 Training
# Epoch:  4 	 batch:  30 	 Training
# Epoch:  4 	 batch:  31 	 Training
# Epoch:  4 	 batch:  32 	 Training
# Epoch:  4 	 batch:  33 	 Training
# Epoch:  4 	 batch:  34 	 Training
# Epoch:  4 	 batch:  35 	 Training
# Epoch:  4 	 batch:  36 	 Training
# Epoch:  4 	 batch:  37 	 Training
# Epoch:  4 	 batch:  38 	 Training
# Epoch:  4 	 batch:  39 	 Training
# Epoch:  4 	 batch:  40 	 Training
# Epoch:  4 	 batch:  41 	 Training
# Epoch:  4 	 batch:  42 	 Training
# Epoch:  4 	 batch:  43 	 Training
# Epoch:  4 	 batch:  44 	 Training
# Epoch:  4 	 batch:  45 	 Training
# Epoch:  4 	 batch:  46 	 Training
# Epoch:  4 	 batch:  47 	 Training
# Epoch:  4 	 batch:  48 	 Training
# Epoch:  4 	 batch:  49 	 Training
# Epoch:  4 	 batch:  50 	 Training
# Epoch:  4 	 batch:  51 	 Training
# Epoch:  4 	 batch:  52 	 Training
# Epoch:  4 	 batch:  53 	 Training
# Epoch:  4 	 batch:  54 	 Training
# Epoch:  4 	 batch:  55 	 Training
# Epoch:  4 	 batch:  56 	 Training
# Epoch:  4 	batch:  0 	Validating
# Epoch:  4 	batch:  1 	Validating
# Epoch:  4 	batch:  2 	Validating
# Epoch:  4 	batch:  3 	Validating
# Epoch:  4 	batch:  4 	Validating
# Epoch:  4 	batch:  5 	Validating
# Epoch:  4 	batch:  6 	Validating
# Epoch:  4 	batch:  7 	Validating
# Epoch:  4 	batch:  8 	Validating
# Epoch:  4 	batch:  9 	Validating
# Epoch:  4 	batch:  10 	Validating
# Epoch:  4 	batch:  11 	Validating
# Epoch:  5 	 batch:  0 	 Training
# Epoch:  5 	 batch:  1 	 Training
# Epoch:  5 	 batch:  2 	 Training
# Epoch:  5 	 batch:  3 	 Training
# Epoch:  5 	 batch:  4 	 Training
# Epoch:  5 	 batch:  5 	 Training
# Epoch:  5 	 batch:  6 	 Training
# Epoch:  5 	 batch:  7 	 Training
# Epoch:  5 	 batch:  8 	 Training
# Epoch:  5 	 batch:  9 	 Training
# Epoch:  5 	 batch:  10 	 Training
# Epoch:  5 	 batch:  11 	 Training
# Epoch:  5 	 batch:  12 	 Training
# Epoch:  5 	 batch:  13 	 Training
# Epoch:  5 	 batch:  14 	 Training
# Epoch:  5 	 batch:  15 	 Training
# Epoch:  5 	 batch:  16 	 Training
# Epoch:  5 	 batch:  17 	 Training
# Epoch:  5 	 batch:  18 	 Training
# Epoch:  5 	 batch:  19 	 Training
# Epoch:  5 	 batch:  20 	 Training
# Epoch:  5 	 batch:  21 	 Training
# Epoch:  5 	 batch:  22 	 Training
# Epoch:  5 	 batch:  23 	 Training
# Epoch:  5 	 batch:  24 	 Training
# Epoch:  5 	 batch:  25 	 Training
# Epoch:  5 	 batch:  26 	 Training
# Epoch:  5 	 batch:  27 	 Training
# Epoch:  5 	 batch:  28 	 Training
# Epoch:  5 	 batch:  29 	 Training
# Epoch:  5 	 batch:  30 	 Training
# Epoch:  5 	 batch:  31 	 Training
# Epoch:  5 	 batch:  32 	 Training
# Epoch:  5 	 batch:  33 	 Training
# Epoch:  5 	 batch:  34 	 Training
# Epoch:  5 	 batch:  35 	 Training
# Epoch:  5 	 batch:  36 	 Training
# Epoch:  5 	 batch:  37 	 Training
# Epoch:  5 	 batch:  38 	 Training
# Epoch:  5 	 batch:  39 	 Training
# Epoch:  5 	 batch:  40 	 Training
# Epoch:  5 	 batch:  41 	 Training
# Epoch:  5 	 batch:  42 	 Training
# Epoch:  5 	 batch:  43 	 Training
# Epoch:  5 	 batch:  44 	 Training
# Epoch:  5 	 batch:  45 	 Training
# Epoch:  5 	 batch:  46 	 Training
# Epoch:  5 	 batch:  47 	 Training
# Epoch:  5 	 batch:  48 	 Training
# Epoch:  5 	 batch:  49 	 Training
# Epoch:  5 	 batch:  50 	 Training
# Epoch:  5 	 batch:  51 	 Training
# Epoch:  5 	 batch:  52 	 Training
# Epoch:  5 	 batch:  53 	 Training
# Epoch:  5 	 batch:  54 	 Training
# Epoch:  5 	 batch:  55 	 Training
# Epoch:  5 	 batch:  56 	 Training
# Epoch:  5 	batch:  0 	Validating
# Epoch:  5 	batch:  1 	Validating
# Epoch:  5 	batch:  2 	Validating
# Epoch:  5 	batch:  3 	Validating
# Epoch:  5 	batch:  4 	Validating
# Epoch:  5 	batch:  5 	Validating
# Epoch:  5 	batch:  6 	Validating
# Epoch:  5 	batch:  7 	Validating
# Epoch:  5 	batch:  8 	Validating
# Epoch:  5 	batch:  9 	Validating
# Epoch:  5 	batch:  10 	Validating
# Epoch:  5 	batch:  11 	Validating
# Epoch:  6 	 batch:  0 	 Training
# Epoch:  6 	 batch:  1 	 Training
# Epoch:  6 	 batch:  2 	 Training
# Epoch:  6 	 batch:  3 	 Training
# Epoch:  6 	 batch:  4 	 Training
# Epoch:  6 	 batch:  5 	 Training
# Epoch:  6 	 batch:  6 	 Training
# Epoch:  6 	 batch:  7 	 Training
# Epoch:  6 	 batch:  8 	 Training
# Epoch:  6 	 batch:  9 	 Training
# Epoch:  6 	 batch:  10 	 Training
# Epoch:  6 	 batch:  11 	 Training
# Epoch:  6 	 batch:  12 	 Training
# Epoch:  6 	 batch:  13 	 Training
# Epoch:  6 	 batch:  14 	 Training
# Epoch:  6 	 batch:  15 	 Training
# Epoch:  6 	 batch:  16 	 Training
# Epoch:  6 	 batch:  17 	 Training
# Epoch:  6 	 batch:  18 	 Training
# Epoch:  6 	 batch:  19 	 Training
# Epoch:  6 	 batch:  20 	 Training
# Epoch:  6 	 batch:  21 	 Training
# Epoch:  6 	 batch:  22 	 Training
# Epoch:  6 	 batch:  23 	 Training
# Epoch:  6 	 batch:  24 	 Training
# Epoch:  6 	 batch:  25 	 Training
# Epoch:  6 	 batch:  26 	 Training
# Epoch:  6 	 batch:  27 	 Training
# Epoch:  6 	 batch:  28 	 Training
# Epoch:  6 	 batch:  29 	 Training
# Epoch:  6 	 batch:  30 	 Training
# Epoch:  6 	 batch:  31 	 Training
# Epoch:  6 	 batch:  32 	 Training
# Epoch:  6 	 batch:  33 	 Training
# Epoch:  6 	 batch:  34 	 Training
# Epoch:  6 	 batch:  35 	 Training
# Epoch:  6 	 batch:  36 	 Training
# Epoch:  6 	 batch:  37 	 Training
# Epoch:  6 	 batch:  38 	 Training
# Epoch:  6 	 batch:  39 	 Training
# Epoch:  6 	 batch:  40 	 Training
# Epoch:  6 	 batch:  41 	 Training
# Epoch:  6 	 batch:  42 	 Training
# Epoch:  6 	 batch:  43 	 Training
# Epoch:  6 	 batch:  44 	 Training
# Epoch:  6 	 batch:  45 	 Training
# Epoch:  6 	 batch:  46 	 Training
# Epoch:  6 	 batch:  47 	 Training
# Epoch:  6 	 batch:  48 	 Training
# Epoch:  6 	 batch:  49 	 Training
# Epoch:  6 	 batch:  50 	 Training
# Epoch:  6 	 batch:  51 	 Training
# Epoch:  6 	 batch:  52 	 Training
# Epoch:  6 	 batch:  53 	 Training
# Epoch:  6 	 batch:  54 	 Training
# Epoch:  6 	 batch:  55 	 Training
# Epoch:  6 	 batch:  56 	 Training
# Epoch:  6 	batch:  0 	Validating
# Epoch:  6 	batch:  1 	Validating
# Epoch:  6 	batch:  2 	Validating
# Epoch:  6 	batch:  3 	Validating
# Epoch:  6 	batch:  4 	Validating
# Epoch:  6 	batch:  5 	Validating
# Epoch:  6 	batch:  6 	Validating
# Epoch:  6 	batch:  7 	Validating
# Epoch:  6 	batch:  8 	Validating
# Epoch:  6 	batch:  9 	Validating
# Epoch:  6 	batch:  10 	Validating
# Epoch:  6 	batch:  11 	Validating
# Epoch:  7 	 batch:  0 	 Training
# Epoch:  7 	 batch:  1 	 Training
# Epoch:  7 	 batch:  2 	 Training
# Epoch:  7 	 batch:  3 	 Training
# Epoch:  7 	 batch:  4 	 Training
# Epoch:  7 	 batch:  5 	 Training
# Epoch:  7 	 batch:  6 	 Training
# Epoch:  7 	 batch:  7 	 Training
# Epoch:  7 	 batch:  8 	 Training
# Epoch:  7 	 batch:  9 	 Training
# Epoch:  7 	 batch:  10 	 Training
# Epoch:  7 	 batch:  11 	 Training
# Epoch:  7 	 batch:  12 	 Training
# Epoch:  7 	 batch:  13 	 Training
# Epoch:  7 	 batch:  14 	 Training
# Epoch:  7 	 batch:  15 	 Training
# Epoch:  7 	 batch:  16 	 Training
# Epoch:  7 	 batch:  17 	 Training
# Epoch:  7 	 batch:  18 	 Training
# Epoch:  7 	 batch:  19 	 Training
# Epoch:  7 	 batch:  20 	 Training
# Epoch:  7 	 batch:  21 	 Training
# Epoch:  7 	 batch:  22 	 Training
# Epoch:  7 	 batch:  23 	 Training
# Epoch:  7 	 batch:  24 	 Training
# Epoch:  7 	 batch:  25 	 Training
# Epoch:  7 	 batch:  26 	 Training
# Epoch:  7 	 batch:  27 	 Training
# Epoch:  7 	 batch:  28 	 Training
# Epoch:  7 	 batch:  29 	 Training
# Epoch:  7 	 batch:  30 	 Training
# Epoch:  7 	 batch:  31 	 Training
# Epoch:  7 	 batch:  32 	 Training
# Epoch:  7 	 batch:  33 	 Training
# Epoch:  7 	 batch:  34 	 Training
# Epoch:  7 	 batch:  35 	 Training
# Epoch:  7 	 batch:  36 	 Training
# Epoch:  7 	 batch:  37 	 Training
# Epoch:  7 	 batch:  38 	 Training
# Epoch:  7 	 batch:  39 	 Training
# Epoch:  7 	 batch:  40 	 Training
# Epoch:  7 	 batch:  41 	 Training
# Epoch:  7 	 batch:  42 	 Training
# Epoch:  7 	 batch:  43 	 Training
# Epoch:  7 	 batch:  44 	 Training
# Epoch:  7 	 batch:  45 	 Training
# Epoch:  7 	 batch:  46 	 Training
# Epoch:  7 	 batch:  47 	 Training
# Epoch:  7 	 batch:  48 	 Training
# Epoch:  7 	 batch:  49 	 Training
# Epoch:  7 	 batch:  50 	 Training
# Epoch:  7 	 batch:  51 	 Training
# Epoch:  7 	 batch:  52 	 Training
# Epoch:  7 	 batch:  53 	 Training
# Epoch:  7 	 batch:  54 	 Training
# Epoch:  7 	 batch:  55 	 Training
# Epoch:  7 	 batch:  56 	 Training
# Epoch:  7 	batch:  0 	Validating
# Epoch:  7 	batch:  1 	Validating
# Epoch:  7 	batch:  2 	Validating
# Epoch:  7 	batch:  3 	Validating
# Epoch:  7 	batch:  4 	Validating
# Epoch:  7 	batch:  5 	Validating
# Epoch:  7 	batch:  6 	Validating
# Epoch:  7 	batch:  7 	Validating
# Epoch:  7 	batch:  8 	Validating
# Epoch:  7 	batch:  9 	Validating
# Epoch:  7 	batch:  10 	Validating
# Epoch:  7 	batch:  11 	Validating
# Epoch:  8 	 batch:  0 	 Training
# Epoch:  8 	 batch:  1 	 Training
# Epoch:  8 	 batch:  2 	 Training
# Epoch:  8 	 batch:  3 	 Training
# Epoch:  8 	 batch:  4 	 Training
# Epoch:  8 	 batch:  5 	 Training
# Epoch:  8 	 batch:  6 	 Training
# Epoch:  8 	 batch:  7 	 Training
# Epoch:  8 	 batch:  8 	 Training
# Epoch:  8 	 batch:  9 	 Training
# Epoch:  8 	 batch:  10 	 Training
# Epoch:  8 	 batch:  11 	 Training
# Epoch:  8 	 batch:  12 	 Training
# Epoch:  8 	 batch:  13 	 Training
# Epoch:  8 	 batch:  14 	 Training
# Epoch:  8 	 batch:  15 	 Training
# Epoch:  8 	 batch:  16 	 Training
# Epoch:  8 	 batch:  17 	 Training
# Epoch:  8 	 batch:  18 	 Training
# Epoch:  8 	 batch:  19 	 Training
# Epoch:  8 	 batch:  20 	 Training
# Epoch:  8 	 batch:  21 	 Training
# Epoch:  8 	 batch:  22 	 Training
# Epoch:  8 	 batch:  23 	 Training
# Epoch:  8 	 batch:  24 	 Training
# Epoch:  8 	 batch:  25 	 Training
# Epoch:  8 	 batch:  26 	 Training
# Epoch:  8 	 batch:  27 	 Training
# Epoch:  8 	 batch:  28 	 Training
# Epoch:  8 	 batch:  29 	 Training
# Epoch:  8 	 batch:  30 	 Training
# Epoch:  8 	 batch:  31 	 Training
# Epoch:  8 	 batch:  32 	 Training
# Epoch:  8 	 batch:  33 	 Training
# Epoch:  8 	 batch:  34 	 Training
# Epoch:  8 	 batch:  35 	 Training
# Epoch:  8 	 batch:  36 	 Training
# Epoch:  8 	 batch:  37 	 Training
# Epoch:  8 	 batch:  38 	 Training
# Epoch:  8 	 batch:  39 	 Training
# Epoch:  8 	 batch:  40 	 Training
# Epoch:  8 	 batch:  41 	 Training
# Epoch:  8 	 batch:  42 	 Training
# Epoch:  8 	 batch:  43 	 Training
# Epoch:  8 	 batch:  44 	 Training
# Epoch:  8 	 batch:  45 	 Training
# Epoch:  8 	 batch:  46 	 Training
# Epoch:  8 	 batch:  47 	 Training
# Epoch:  8 	 batch:  48 	 Training
# Epoch:  8 	 batch:  49 	 Training
# Epoch:  8 	 batch:  50 	 Training
# Epoch:  8 	 batch:  51 	 Training
# Epoch:  8 	 batch:  52 	 Training
# Epoch:  8 	 batch:  53 	 Training
# Epoch:  8 	 batch:  54 	 Training
# Epoch:  8 	 batch:  55 	 Training
# Epoch:  8 	 batch:  56 	 Training
# Epoch:  8 	batch:  0 	Validating
# Epoch:  8 	batch:  1 	Validating
# Epoch:  8 	batch:  2 	Validating
# Epoch:  8 	batch:  3 	Validating
# Epoch:  8 	batch:  4 	Validating
# Epoch:  8 	batch:  5 	Validating
# Epoch:  8 	batch:  6 	Validating
# Epoch:  8 	batch:  7 	Validating
# Epoch:  8 	batch:  8 	Validating
# Epoch:  8 	batch:  9 	Validating
# Epoch:  8 	batch:  10 	Validating
# Epoch:  8 	batch:  11 	Validating
# Epoch:  9 	 batch:  0 	 Training
# Epoch:  9 	 batch:  1 	 Training
# Epoch:  9 	 batch:  2 	 Training
# Epoch:  9 	 batch:  3 	 Training
# Epoch:  9 	 batch:  4 	 Training
# Epoch:  9 	 batch:  5 	 Training
# Epoch:  9 	 batch:  6 	 Training
# Epoch:  9 	 batch:  7 	 Training
# Epoch:  9 	 batch:  8 	 Training
# Epoch:  9 	 batch:  9 	 Training
# Epoch:  9 	 batch:  10 	 Training
# Epoch:  9 	 batch:  11 	 Training
# Epoch:  9 	 batch:  12 	 Training
# Epoch:  9 	 batch:  13 	 Training
# Epoch:  9 	 batch:  14 	 Training
# Epoch:  9 	 batch:  15 	 Training
# Epoch:  9 	 batch:  16 	 Training
# Epoch:  9 	 batch:  17 	 Training
# Epoch:  9 	 batch:  18 	 Training
# Epoch:  9 	 batch:  19 	 Training
# Epoch:  9 	 batch:  20 	 Training
# Epoch:  9 	 batch:  21 	 Training
# Epoch:  9 	 batch:  22 	 Training
# Epoch:  9 	 batch:  23 	 Training
# Epoch:  9 	 batch:  24 	 Training
# Epoch:  9 	 batch:  25 	 Training
# Epoch:  9 	 batch:  26 	 Training
# Epoch:  9 	 batch:  27 	 Training
# Epoch:  9 	 batch:  28 	 Training
# Epoch:  9 	 batch:  29 	 Training
# Epoch:  9 	 batch:  30 	 Training
# Epoch:  9 	 batch:  31 	 Training
# Epoch:  9 	 batch:  32 	 Training
# Epoch:  9 	 batch:  33 	 Training
# Epoch:  9 	 batch:  34 	 Training
# Epoch:  9 	 batch:  35 	 Training
# Epoch:  9 	 batch:  36 	 Training
# Epoch:  9 	 batch:  37 	 Training
# Epoch:  9 	 batch:  38 	 Training
# Epoch:  9 	 batch:  39 	 Training
# Epoch:  9 	 batch:  40 	 Training
# Epoch:  9 	 batch:  41 	 Training
# Epoch:  9 	 batch:  42 	 Training
# Epoch:  9 	 batch:  43 	 Training
# Epoch:  9 	 batch:  44 	 Training
# Epoch:  9 	 batch:  45 	 Training
# Epoch:  9 	 batch:  46 	 Training
# Epoch:  9 	 batch:  47 	 Training
# Epoch:  9 	 batch:  48 	 Training
# Epoch:  9 	 batch:  49 	 Training
# Epoch:  9 	 batch:  50 	 Training
# Epoch:  9 	 batch:  51 	 Training
# Epoch:  9 	 batch:  52 	 Training
# Epoch:  9 	 batch:  53 	 Training
# Epoch:  9 	 batch:  54 	 Training
# Epoch:  9 	 batch:  55 	 Training
# Epoch:  9 	 batch:  56 	 Training
# Epoch:  9 	batch:  0 	Validating
# Epoch:  9 	batch:  1 	Validating
# Epoch:  9 	batch:  2 	Validating
# Epoch:  9 	batch:  3 	Validating
# Epoch:  9 	batch:  4 	Validating
# Epoch:  9 	batch:  5 	Validating
# Epoch:  9 	batch:  6 	Validating
# Epoch:  9 	batch:  7 	Validating
# Epoch:  9 	batch:  8 	Validating
# Epoch:  9 	batch:  9 	Validating
# Epoch:  9 	batch:  10 	Validating
# Epoch:  9 	batch:  11 	Validating
# Epoch:  10 	 batch:  0 	 Training
# Epoch:  10 	 batch:  1 	 Training
# Epoch:  10 	 batch:  2 	 Training
# Epoch:  10 	 batch:  3 	 Training
# Epoch:  10 	 batch:  4 	 Training
# Epoch:  10 	 batch:  5 	 Training
# Epoch:  10 	 batch:  6 	 Training
# Epoch:  10 	 batch:  7 	 Training
# Epoch:  10 	 batch:  8 	 Training
# Epoch:  10 	 batch:  9 	 Training
# Epoch:  10 	 batch:  10 	 Training
# Epoch:  10 	 batch:  11 	 Training
# Epoch:  10 	 batch:  12 	 Training
# Epoch:  10 	 batch:  13 	 Training
# Epoch:  10 	 batch:  14 	 Training
# Epoch:  10 	 batch:  15 	 Training
# Epoch:  10 	 batch:  16 	 Training
# Epoch:  10 	 batch:  17 	 Training
# Epoch:  10 	 batch:  18 	 Training
# Epoch:  10 	 batch:  19 	 Training
# Epoch:  10 	 batch:  20 	 Training
# Epoch:  10 	 batch:  21 	 Training
# Epoch:  10 	 batch:  22 	 Training
# Epoch:  10 	 batch:  23 	 Training
# Epoch:  10 	 batch:  24 	 Training
# Epoch:  10 	 batch:  25 	 Training
# Epoch:  10 	 batch:  26 	 Training
# Epoch:  10 	 batch:  27 	 Training
# Epoch:  10 	 batch:  28 	 Training
# Epoch:  10 	 batch:  29 	 Training
# Epoch:  10 	 batch:  30 	 Training
# Epoch:  10 	 batch:  31 	 Training
# Epoch:  10 	 batch:  32 	 Training
# Epoch:  10 	 batch:  33 	 Training
# Epoch:  10 	 batch:  34 	 Training
# Epoch:  10 	 batch:  35 	 Training
# Epoch:  10 	 batch:  36 	 Training
# Epoch:  10 	 batch:  37 	 Training
# Epoch:  10 	 batch:  38 	 Training
# Epoch:  10 	 batch:  39 	 Training
# Epoch:  10 	 batch:  40 	 Training
# Epoch:  10 	 batch:  41 	 Training
# Epoch:  10 	 batch:  42 	 Training
# Epoch:  10 	 batch:  43 	 Training
# Epoch:  10 	 batch:  44 	 Training
# Epoch:  10 	 batch:  45 	 Training
# Epoch:  10 	 batch:  46 	 Training
# Epoch:  10 	 batch:  47 	 Training
# Epoch:  10 	 batch:  48 	 Training
# Epoch:  10 	 batch:  49 	 Training
# Epoch:  10 	 batch:  50 	 Training
# Epoch:  10 	 batch:  51 	 Training
# Epoch:  10 	 batch:  52 	 Training
# Epoch:  10 	 batch:  53 	 Training
# Epoch:  10 	 batch:  54 	 Training
# Epoch:  10 	 batch:  55 	 Training
# Epoch:  10 	 batch:  56 	 Training
# Epoch:  10 	batch:  0 	Validating
# Epoch:  10 	batch:  1 	Validating
# Epoch:  10 	batch:  2 	Validating
# Epoch:  10 	batch:  3 	Validating
# Epoch:  10 	batch:  4 	Validating
# Epoch:  10 	batch:  5 	Validating
# Epoch:  10 	batch:  6 	Validating
# Epoch:  10 	batch:  7 	Validating
# Epoch:  10 	batch:  8 	Validating
# Epoch:  10 	batch:  9 	Validating
# Epoch:  10 	batch:  10 	Validating
# Epoch:  10 	batch:  11 	Validating
# Epoch:  11 	 batch:  0 	 Training
# Epoch:  11 	 batch:  1 	 Training
# Epoch:  11 	 batch:  2 	 Training
# Epoch:  11 	 batch:  3 	 Training
# Epoch:  11 	 batch:  4 	 Training
# Epoch:  11 	 batch:  5 	 Training
# Epoch:  11 	 batch:  6 	 Training
# Epoch:  11 	 batch:  7 	 Training
# Epoch:  11 	 batch:  8 	 Training
# Epoch:  11 	 batch:  9 	 Training
# Epoch:  11 	 batch:  10 	 Training
# Epoch:  11 	 batch:  11 	 Training
# Epoch:  11 	 batch:  12 	 Training
# Epoch:  11 	 batch:  13 	 Training
# Epoch:  11 	 batch:  14 	 Training
# Epoch:  11 	 batch:  15 	 Training
# Epoch:  11 	 batch:  16 	 Training
# Epoch:  11 	 batch:  17 	 Training
# Epoch:  11 	 batch:  18 	 Training
# Epoch:  11 	 batch:  19 	 Training
# Epoch:  11 	 batch:  20 	 Training
# Epoch:  11 	 batch:  21 	 Training
# Epoch:  11 	 batch:  22 	 Training
# Epoch:  11 	 batch:  23 	 Training
# Epoch:  11 	 batch:  24 	 Training
# Epoch:  11 	 batch:  25 	 Training
# Epoch:  11 	 batch:  26 	 Training
# Epoch:  11 	 batch:  27 	 Training
# Epoch:  11 	 batch:  28 	 Training
# Epoch:  11 	 batch:  29 	 Training
# Epoch:  11 	 batch:  30 	 Training
# Epoch:  11 	 batch:  31 	 Training
# Epoch:  11 	 batch:  32 	 Training
# Epoch:  11 	 batch:  33 	 Training
# Epoch:  11 	 batch:  34 	 Training
# Epoch:  11 	 batch:  35 	 Training
# Epoch:  11 	 batch:  36 	 Training
# Epoch:  11 	 batch:  37 	 Training
# Epoch:  11 	 batch:  38 	 Training
# Epoch:  11 	 batch:  39 	 Training
# Epoch:  11 	 batch:  40 	 Training
# Epoch:  11 	 batch:  41 	 Training
# Epoch:  11 	 batch:  42 	 Training
# Epoch:  11 	 batch:  43 	 Training
# Epoch:  11 	 batch:  44 	 Training
# Epoch:  11 	 batch:  45 	 Training
# Epoch:  11 	 batch:  46 	 Training
# Epoch:  11 	 batch:  47 	 Training
# Epoch:  11 	 batch:  48 	 Training
# Epoch:  11 	 batch:  49 	 Training
# Epoch:  11 	 batch:  50 	 Training
# Epoch:  11 	 batch:  51 	 Training
# Epoch:  11 	 batch:  52 	 Training
# Epoch:  11 	 batch:  53 	 Training
# Epoch:  11 	 batch:  54 	 Training
# Epoch:  11 	 batch:  55 	 Training
# Epoch:  11 	 batch:  56 	 Training
# Epoch:  11 	batch:  0 	Validating
# Epoch:  11 	batch:  1 	Validating
# Epoch:  11 	batch:  2 	Validating
# Epoch:  11 	batch:  3 	Validating
# Epoch:  11 	batch:  4 	Validating
# Epoch:  11 	batch:  5 	Validating
# Epoch:  11 	batch:  6 	Validating
# Epoch:  11 	batch:  7 	Validating
# Epoch:  11 	batch:  8 	Validating
# Epoch:  11 	batch:  9 	Validating
# Epoch:  11 	batch:  10 	Validating
# Epoch:  11 	batch:  11 	Validating
# Epoch:  12 	 batch:  0 	 Training
# Epoch:  12 	 batch:  1 	 Training
# Epoch:  12 	 batch:  2 	 Training
# Epoch:  12 	 batch:  3 	 Training
# Epoch:  12 	 batch:  4 	 Training
# Epoch:  12 	 batch:  5 	 Training
# Epoch:  12 	 batch:  6 	 Training
# Epoch:  12 	 batch:  7 	 Training
# Epoch:  12 	 batch:  8 	 Training
# Epoch:  12 	 batch:  9 	 Training
# Epoch:  12 	 batch:  10 	 Training
# Epoch:  12 	 batch:  11 	 Training
# Epoch:  12 	 batch:  12 	 Training
# Epoch:  12 	 batch:  13 	 Training
# Epoch:  12 	 batch:  14 	 Training
# Epoch:  12 	 batch:  15 	 Training
# Epoch:  12 	 batch:  16 	 Training
# Epoch:  12 	 batch:  17 	 Training
# Epoch:  12 	 batch:  18 	 Training
# Epoch:  12 	 batch:  19 	 Training
# Epoch:  12 	 batch:  20 	 Training
# Epoch:  12 	 batch:  21 	 Training
# Epoch:  12 	 batch:  22 	 Training
# Epoch:  12 	 batch:  23 	 Training
# Epoch:  12 	 batch:  24 	 Training
# Epoch:  12 	 batch:  25 	 Training
# Epoch:  12 	 batch:  26 	 Training
# Epoch:  12 	 batch:  27 	 Training
# Epoch:  12 	 batch:  28 	 Training
# Epoch:  12 	 batch:  29 	 Training
# Epoch:  12 	 batch:  30 	 Training
# Epoch:  12 	 batch:  31 	 Training
# Epoch:  12 	 batch:  32 	 Training
# Epoch:  12 	 batch:  33 	 Training
# Epoch:  12 	 batch:  34 	 Training
# Epoch:  12 	 batch:  35 	 Training
# Epoch:  12 	 batch:  36 	 Training
# Epoch:  12 	 batch:  37 	 Training
# Epoch:  12 	 batch:  38 	 Training
# Epoch:  12 	 batch:  39 	 Training
# Epoch:  12 	 batch:  40 	 Training
# Epoch:  12 	 batch:  41 	 Training
# Epoch:  12 	 batch:  42 	 Training
# Epoch:  12 	 batch:  43 	 Training
# Epoch:  12 	 batch:  44 	 Training
# Epoch:  12 	 batch:  45 	 Training
# Epoch:  12 	 batch:  46 	 Training
# Epoch:  12 	 batch:  47 	 Training
# Epoch:  12 	 batch:  48 	 Training
# Epoch:  12 	 batch:  49 	 Training
# Epoch:  12 	 batch:  50 	 Training
# Epoch:  12 	 batch:  51 	 Training
# Epoch:  12 	 batch:  52 	 Training
# Epoch:  12 	 batch:  53 	 Training
# Epoch:  12 	 batch:  54 	 Training
# Epoch:  12 	 batch:  55 	 Training
# Epoch:  12 	 batch:  56 	 Training
# Epoch:  12 	batch:  0 	Validating
# Epoch:  12 	batch:  1 	Validating
# Epoch:  12 	batch:  2 	Validating
# Epoch:  12 	batch:  3 	Validating
# Epoch:  12 	batch:  4 	Validating
# Epoch:  12 	batch:  5 	Validating
# Epoch:  12 	batch:  6 	Validating
# Epoch:  12 	batch:  7 	Validating
# Epoch:  12 	batch:  8 	Validating
# Epoch:  12 	batch:  9 	Validating
# Epoch:  12 	batch:  10 	Validating
# Epoch:  12 	batch:  11 	Validating
# Epoch:  13 	 batch:  0 	 Training
# Epoch:  13 	 batch:  1 	 Training
# Epoch:  13 	 batch:  2 	 Training
# Epoch:  13 	 batch:  3 	 Training
# Epoch:  13 	 batch:  4 	 Training
# Epoch:  13 	 batch:  5 	 Training
# Epoch:  13 	 batch:  6 	 Training
# Epoch:  13 	 batch:  7 	 Training
# Epoch:  13 	 batch:  8 	 Training
# Epoch:  13 	 batch:  9 	 Training
# Epoch:  13 	 batch:  10 	 Training
# Epoch:  13 	 batch:  11 	 Training
# Epoch:  13 	 batch:  12 	 Training
# Epoch:  13 	 batch:  13 	 Training
# Epoch:  13 	 batch:  14 	 Training
# Epoch:  13 	 batch:  15 	 Training
# Epoch:  13 	 batch:  16 	 Training
# Epoch:  13 	 batch:  17 	 Training
# Epoch:  13 	 batch:  18 	 Training
# Epoch:  13 	 batch:  19 	 Training
# Epoch:  13 	 batch:  20 	 Training
# Epoch:  13 	 batch:  21 	 Training
# Epoch:  13 	 batch:  22 	 Training
# Epoch:  13 	 batch:  23 	 Training
# Epoch:  13 	 batch:  24 	 Training
# Epoch:  13 	 batch:  25 	 Training
# Epoch:  13 	 batch:  26 	 Training
# Epoch:  13 	 batch:  27 	 Training
# Epoch:  13 	 batch:  28 	 Training
# Epoch:  13 	 batch:  29 	 Training
# Epoch:  13 	 batch:  30 	 Training
# Epoch:  13 	 batch:  31 	 Training
# Epoch:  13 	 batch:  32 	 Training
# Epoch:  13 	 batch:  33 	 Training
# Epoch:  13 	 batch:  34 	 Training
# Epoch:  13 	 batch:  35 	 Training
# Epoch:  13 	 batch:  36 	 Training
# Epoch:  13 	 batch:  37 	 Training
# Epoch:  13 	 batch:  38 	 Training
# Epoch:  13 	 batch:  39 	 Training
# Epoch:  13 	 batch:  40 	 Training
# Epoch:  13 	 batch:  41 	 Training
# Epoch:  13 	 batch:  42 	 Training
# Epoch:  13 	 batch:  43 	 Training
# Epoch:  13 	 batch:  44 	 Training
# Epoch:  13 	 batch:  45 	 Training
# Epoch:  13 	 batch:  46 	 Training
# Epoch:  13 	 batch:  47 	 Training
# Epoch:  13 	 batch:  48 	 Training
# Epoch:  13 	 batch:  49 	 Training
# Epoch:  13 	 batch:  50 	 Training
# Epoch:  13 	 batch:  51 	 Training
# Epoch:  13 	 batch:  52 	 Training
# Epoch:  13 	 batch:  53 	 Training
# Epoch:  13 	 batch:  54 	 Training
# Epoch:  13 	 batch:  55 	 Training
# Epoch:  13 	 batch:  56 	 Training
# Epoch:  13 	batch:  0 	Validating
# Epoch:  13 	batch:  1 	Validating
# Epoch:  13 	batch:  2 	Validating
# Epoch:  13 	batch:  3 	Validating
# Epoch:  13 	batch:  4 	Validating
# Epoch:  13 	batch:  5 	Validating
# Epoch:  13 	batch:  6 	Validating
# Epoch:  13 	batch:  7 	Validating
# Epoch:  13 	batch:  8 	Validating
# Epoch:  13 	batch:  9 	Validating
# Epoch:  13 	batch:  10 	Validating
# Epoch:  13 	batch:  11 	Validating
# Epoch:  14 	 batch:  0 	 Training
# Epoch:  14 	 batch:  1 	 Training
# Epoch:  14 	 batch:  2 	 Training
# Epoch:  14 	 batch:  3 	 Training
# Epoch:  14 	 batch:  4 	 Training
# Epoch:  14 	 batch:  5 	 Training
# Epoch:  14 	 batch:  6 	 Training
# Epoch:  14 	 batch:  7 	 Training
# Epoch:  14 	 batch:  8 	 Training
# Epoch:  14 	 batch:  9 	 Training
# Epoch:  14 	 batch:  10 	 Training
# Epoch:  14 	 batch:  11 	 Training
# Epoch:  14 	 batch:  12 	 Training
# Epoch:  14 	 batch:  13 	 Training
# Epoch:  14 	 batch:  14 	 Training
# Epoch:  14 	 batch:  15 	 Training
# Epoch:  14 	 batch:  16 	 Training
# Epoch:  14 	 batch:  17 	 Training
# Epoch:  14 	 batch:  18 	 Training
# Epoch:  14 	 batch:  19 	 Training
# Epoch:  14 	 batch:  20 	 Training
# Epoch:  14 	 batch:  21 	 Training
# Epoch:  14 	 batch:  22 	 Training
# Epoch:  14 	 batch:  23 	 Training
# Epoch:  14 	 batch:  24 	 Training
# Epoch:  14 	 batch:  25 	 Training
# Epoch:  14 	 batch:  26 	 Training
# Epoch:  14 	 batch:  27 	 Training
# Epoch:  14 	 batch:  28 	 Training
# Epoch:  14 	 batch:  29 	 Training
# Epoch:  14 	 batch:  30 	 Training
# Epoch:  14 	 batch:  31 	 Training
# Epoch:  14 	 batch:  32 	 Training
# Epoch:  14 	 batch:  33 	 Training
# Epoch:  14 	 batch:  34 	 Training
# Epoch:  14 	 batch:  35 	 Training
# Epoch:  14 	 batch:  36 	 Training
# Epoch:  14 	 batch:  37 	 Training
# Epoch:  14 	 batch:  38 	 Training
# Epoch:  14 	 batch:  39 	 Training
# Epoch:  14 	 batch:  40 	 Training
# Epoch:  14 	 batch:  41 	 Training
# Epoch:  14 	 batch:  42 	 Training
# Epoch:  14 	 batch:  43 	 Training
# Epoch:  14 	 batch:  44 	 Training
# Epoch:  14 	 batch:  45 	 Training
# Epoch:  14 	 batch:  46 	 Training
# Epoch:  14 	 batch:  47 	 Training
# Epoch:  14 	 batch:  48 	 Training
# Epoch:  14 	 batch:  49 	 Training
# Epoch:  14 	 batch:  50 	 Training
# Epoch:  14 	 batch:  51 	 Training
# Epoch:  14 	 batch:  52 	 Training
# Epoch:  14 	 batch:  53 	 Training
# Epoch:  14 	 batch:  54 	 Training
# Epoch:  14 	 batch:  55 	 Training
# Epoch:  14 	 batch:  56 	 Training
# Epoch:  14 	batch:  0 	Validating
# Epoch:  14 	batch:  1 	Validating
# Epoch:  14 	batch:  2 	Validating
# Epoch:  14 	batch:  3 	Validating
# Epoch:  14 	batch:  4 	Validating
# Epoch:  14 	batch:  5 	Validating
# Epoch:  14 	batch:  6 	Validating
# Epoch:  14 	batch:  7 	Validating
# Epoch:  14 	batch:  8 	Validating
# Epoch:  14 	batch:  9 	Validating
# Epoch:  14 	batch:  10 	Validating
# Epoch:  14 	batch:  11 	Validating
# Epoch:  15 	 batch:  0 	 Training
# Epoch:  15 	 batch:  1 	 Training
# Epoch:  15 	 batch:  2 	 Training
# Epoch:  15 	 batch:  3 	 Training
# Epoch:  15 	 batch:  4 	 Training
# Epoch:  15 	 batch:  5 	 Training
# Epoch:  15 	 batch:  6 	 Training
# Epoch:  15 	 batch:  7 	 Training
# Epoch:  15 	 batch:  8 	 Training
# Epoch:  15 	 batch:  9 	 Training
# Epoch:  15 	 batch:  10 	 Training
# Epoch:  15 	 batch:  11 	 Training
# Epoch:  15 	 batch:  12 	 Training
# Epoch:  15 	 batch:  13 	 Training
# Epoch:  15 	 batch:  14 	 Training
# Epoch:  15 	 batch:  15 	 Training
# Epoch:  15 	 batch:  16 	 Training
# Epoch:  15 	 batch:  17 	 Training
# Epoch:  15 	 batch:  18 	 Training
# Epoch:  15 	 batch:  19 	 Training
# Epoch:  15 	 batch:  20 	 Training
# Epoch:  15 	 batch:  21 	 Training
# Epoch:  15 	 batch:  22 	 Training
# Epoch:  15 	 batch:  23 	 Training
# Epoch:  15 	 batch:  24 	 Training
# Epoch:  15 	 batch:  25 	 Training
# Epoch:  15 	 batch:  26 	 Training
# Epoch:  15 	 batch:  27 	 Training
# Epoch:  15 	 batch:  28 	 Training
# Epoch:  15 	 batch:  29 	 Training
# Epoch:  15 	 batch:  30 	 Training
# Epoch:  15 	 batch:  31 	 Training
# Epoch:  15 	 batch:  32 	 Training
# Epoch:  15 	 batch:  33 	 Training
# Epoch:  15 	 batch:  34 	 Training
# Epoch:  15 	 batch:  35 	 Training
# Epoch:  15 	 batch:  36 	 Training
# Epoch:  15 	 batch:  37 	 Training
# Epoch:  15 	 batch:  38 	 Training
# Epoch:  15 	 batch:  39 	 Training
# Epoch:  15 	 batch:  40 	 Training
# Epoch:  15 	 batch:  41 	 Training
# Epoch:  15 	 batch:  42 	 Training
# Epoch:  15 	 batch:  43 	 Training
# Epoch:  15 	 batch:  44 	 Training
# Epoch:  15 	 batch:  45 	 Training
# Epoch:  15 	 batch:  46 	 Training
# Epoch:  15 	 batch:  47 	 Training
# Epoch:  15 	 batch:  48 	 Training
# Epoch:  15 	 batch:  49 	 Training
# Epoch:  15 	 batch:  50 	 Training
# Epoch:  15 	 batch:  51 	 Training
# Epoch:  15 	 batch:  52 	 Training
# Epoch:  15 	 batch:  53 	 Training
# Epoch:  15 	 batch:  54 	 Training
# Epoch:  15 	 batch:  55 	 Training
# Epoch:  15 	 batch:  56 	 Training
# Epoch:  15 	batch:  0 	Validating
# Epoch:  15 	batch:  1 	Validating
# Epoch:  15 	batch:  2 	Validating
# Epoch:  15 	batch:  3 	Validating
# Epoch:  15 	batch:  4 	Validating
# Epoch:  15 	batch:  5 	Validating
# Epoch:  15 	batch:  6 	Validating
# Epoch:  15 	batch:  7 	Validating
# Epoch:  15 	batch:  8 	Validating
# Epoch:  15 	batch:  9 	Validating
# Epoch:  15 	batch:  10 	Validating
# Epoch:  15 	batch:  11 	Validating
# Epoch:  16 	 batch:  0 	 Training
# Epoch:  16 	 batch:  1 	 Training
# Epoch:  16 	 batch:  2 	 Training
# Epoch:  16 	 batch:  3 	 Training
# Epoch:  16 	 batch:  4 	 Training
# Epoch:  16 	 batch:  5 	 Training
# Epoch:  16 	 batch:  6 	 Training
# Epoch:  16 	 batch:  7 	 Training
# Epoch:  16 	 batch:  8 	 Training
# Epoch:  16 	 batch:  9 	 Training
# Epoch:  16 	 batch:  10 	 Training
# Epoch:  16 	 batch:  11 	 Training
# Epoch:  16 	 batch:  12 	 Training
# Epoch:  16 	 batch:  13 	 Training
# Epoch:  16 	 batch:  14 	 Training
# Epoch:  16 	 batch:  15 	 Training
# Epoch:  16 	 batch:  16 	 Training
# Epoch:  16 	 batch:  17 	 Training
# Epoch:  16 	 batch:  18 	 Training
# Epoch:  16 	 batch:  19 	 Training
# Epoch:  16 	 batch:  20 	 Training
# Epoch:  16 	 batch:  21 	 Training
# Epoch:  16 	 batch:  22 	 Training
# Epoch:  16 	 batch:  23 	 Training
# Epoch:  16 	 batch:  24 	 Training
# Epoch:  16 	 batch:  25 	 Training
# Epoch:  16 	 batch:  26 	 Training
# Epoch:  16 	 batch:  27 	 Training
# Epoch:  16 	 batch:  28 	 Training
# Epoch:  16 	 batch:  29 	 Training
# Epoch:  16 	 batch:  30 	 Training
# Epoch:  16 	 batch:  31 	 Training
# Epoch:  16 	 batch:  32 	 Training
# Epoch:  16 	 batch:  33 	 Training
# Epoch:  16 	 batch:  34 	 Training
# Epoch:  16 	 batch:  35 	 Training
# Epoch:  16 	 batch:  36 	 Training
# Epoch:  16 	 batch:  37 	 Training
# Epoch:  16 	 batch:  38 	 Training
# Epoch:  16 	 batch:  39 	 Training
# Epoch:  16 	 batch:  40 	 Training
# Epoch:  16 	 batch:  41 	 Training
# Epoch:  16 	 batch:  42 	 Training
# Epoch:  16 	 batch:  43 	 Training
# Epoch:  16 	 batch:  44 	 Training
# Epoch:  16 	 batch:  45 	 Training
# Epoch:  16 	 batch:  46 	 Training
# Epoch:  16 	 batch:  47 	 Training
# Epoch:  16 	 batch:  48 	 Training
# Epoch:  16 	 batch:  49 	 Training
# Epoch:  16 	 batch:  50 	 Training
# Epoch:  16 	 batch:  51 	 Training
# Epoch:  16 	 batch:  52 	 Training
# Epoch:  16 	 batch:  53 	 Training
# Epoch:  16 	 batch:  54 	 Training
# Epoch:  16 	 batch:  55 	 Training
# Epoch:  16 	 batch:  56 	 Training
# Epoch:  16 	batch:  0 	Validating
# Epoch:  16 	batch:  1 	Validating
# Epoch:  16 	batch:  2 	Validating
# Epoch:  16 	batch:  3 	Validating
# Epoch:  16 	batch:  4 	Validating
# Epoch:  16 	batch:  5 	Validating
# Epoch:  16 	batch:  6 	Validating
# Epoch:  16 	batch:  7 	Validating
# Epoch:  16 	batch:  8 	Validating
# Epoch:  16 	batch:  9 	Validating
# Epoch:  16 	batch:  10 	Validating
# Epoch:  16 	batch:  11 	Validating
# Epoch:  17 	 batch:  0 	 Training
# Epoch:  17 	 batch:  1 	 Training
# Epoch:  17 	 batch:  2 	 Training
# Epoch:  17 	 batch:  3 	 Training
# Epoch:  17 	 batch:  4 	 Training
# Epoch:  17 	 batch:  5 	 Training
# Epoch:  17 	 batch:  6 	 Training
# Epoch:  17 	 batch:  7 	 Training
# Epoch:  17 	 batch:  8 	 Training
# Epoch:  17 	 batch:  9 	 Training
# Epoch:  17 	 batch:  10 	 Training
# Epoch:  17 	 batch:  11 	 Training
# Epoch:  17 	 batch:  12 	 Training
# Epoch:  17 	 batch:  13 	 Training
# Epoch:  17 	 batch:  14 	 Training
# Epoch:  17 	 batch:  15 	 Training
# Epoch:  17 	 batch:  16 	 Training
# Epoch:  17 	 batch:  17 	 Training
# Epoch:  17 	 batch:  18 	 Training
# Epoch:  17 	 batch:  19 	 Training
# Epoch:  17 	 batch:  20 	 Training
# Epoch:  17 	 batch:  21 	 Training
# Epoch:  17 	 batch:  22 	 Training
# Epoch:  17 	 batch:  23 	 Training
# Epoch:  17 	 batch:  24 	 Training
# Epoch:  17 	 batch:  25 	 Training
# Epoch:  17 	 batch:  26 	 Training
# Epoch:  17 	 batch:  27 	 Training
# Epoch:  17 	 batch:  28 	 Training
# Epoch:  17 	 batch:  29 	 Training
# Epoch:  17 	 batch:  30 	 Training
# Epoch:  17 	 batch:  31 	 Training
# Epoch:  17 	 batch:  32 	 Training
# Epoch:  17 	 batch:  33 	 Training
# Epoch:  17 	 batch:  34 	 Training
# Epoch:  17 	 batch:  35 	 Training
# Epoch:  17 	 batch:  36 	 Training
# Epoch:  17 	 batch:  37 	 Training
# Epoch:  17 	 batch:  38 	 Training
# Epoch:  17 	 batch:  39 	 Training
# Epoch:  17 	 batch:  40 	 Training
# Epoch:  17 	 batch:  41 	 Training
# Epoch:  17 	 batch:  42 	 Training
# Epoch:  17 	 batch:  43 	 Training
# Epoch:  17 	 batch:  44 	 Training
# Epoch:  17 	 batch:  45 	 Training
# Epoch:  17 	 batch:  46 	 Training
# Epoch:  17 	 batch:  47 	 Training
# Epoch:  17 	 batch:  48 	 Training
# Epoch:  17 	 batch:  49 	 Training
# Epoch:  17 	 batch:  50 	 Training
# Epoch:  17 	 batch:  51 	 Training
# Epoch:  17 	 batch:  52 	 Training
# Epoch:  17 	 batch:  53 	 Training
# Epoch:  17 	 batch:  54 	 Training
# Epoch:  17 	 batch:  55 	 Training
# Epoch:  17 	 batch:  56 	 Training
# Epoch:  17 	batch:  0 	Validating
# Epoch:  17 	batch:  1 	Validating
# Epoch:  17 	batch:  2 	Validating
# Epoch:  17 	batch:  3 	Validating
# Epoch:  17 	batch:  4 	Validating
# Epoch:  17 	batch:  5 	Validating
# Epoch:  17 	batch:  6 	Validating
# Epoch:  17 	batch:  7 	Validating
# Epoch:  17 	batch:  8 	Validating
# Epoch:  17 	batch:  9 	Validating
# Epoch:  17 	batch:  10 	Validating
# Epoch:  17 	batch:  11 	Validating
# Epoch:  18 	 batch:  0 	 Training
# Epoch:  18 	 batch:  1 	 Training
# Epoch:  18 	 batch:  2 	 Training
# Epoch:  18 	 batch:  3 	 Training
# Epoch:  18 	 batch:  4 	 Training
# Epoch:  18 	 batch:  5 	 Training
# Epoch:  18 	 batch:  6 	 Training
# Epoch:  18 	 batch:  7 	 Training
# Epoch:  18 	 batch:  8 	 Training
# Epoch:  18 	 batch:  9 	 Training
# Epoch:  18 	 batch:  10 	 Training
# Epoch:  18 	 batch:  11 	 Training
# Epoch:  18 	 batch:  12 	 Training
# Epoch:  18 	 batch:  13 	 Training
# Epoch:  18 	 batch:  14 	 Training
# Epoch:  18 	 batch:  15 	 Training
# Epoch:  18 	 batch:  16 	 Training
# Epoch:  18 	 batch:  17 	 Training
# Epoch:  18 	 batch:  18 	 Training
# Epoch:  18 	 batch:  19 	 Training
# Epoch:  18 	 batch:  20 	 Training
# Epoch:  18 	 batch:  21 	 Training
# Epoch:  18 	 batch:  22 	 Training
# Epoch:  18 	 batch:  23 	 Training
# Epoch:  18 	 batch:  24 	 Training
# Epoch:  18 	 batch:  25 	 Training
# Epoch:  18 	 batch:  26 	 Training
# Epoch:  18 	 batch:  27 	 Training
# Epoch:  18 	 batch:  28 	 Training
# Epoch:  18 	 batch:  29 	 Training
# Epoch:  18 	 batch:  30 	 Training
# Epoch:  18 	 batch:  31 	 Training
# Epoch:  18 	 batch:  32 	 Training
# Epoch:  18 	 batch:  33 	 Training
# Epoch:  18 	 batch:  34 	 Training
# Epoch:  18 	 batch:  35 	 Training
# Epoch:  18 	 batch:  36 	 Training
# Epoch:  18 	 batch:  37 	 Training
# Epoch:  18 	 batch:  38 	 Training
# Epoch:  18 	 batch:  39 	 Training
# Epoch:  18 	 batch:  40 	 Training
# Epoch:  18 	 batch:  41 	 Training
# Epoch:  18 	 batch:  42 	 Training
# Epoch:  18 	 batch:  43 	 Training
# Epoch:  18 	 batch:  44 	 Training
# Epoch:  18 	 batch:  45 	 Training
# Epoch:  18 	 batch:  46 	 Training
# Epoch:  18 	 batch:  47 	 Training
# Epoch:  18 	 batch:  48 	 Training
# Epoch:  18 	 batch:  49 	 Training
# Epoch:  18 	 batch:  50 	 Training
# Epoch:  18 	 batch:  51 	 Training
# Epoch:  18 	 batch:  52 	 Training
# Epoch:  18 	 batch:  53 	 Training
# Epoch:  18 	 batch:  54 	 Training
# Epoch:  18 	 batch:  55 	 Training
# Epoch:  18 	 batch:  56 	 Training
# Epoch:  18 	batch:  0 	Validating
# Epoch:  18 	batch:  1 	Validating
# Epoch:  18 	batch:  2 	Validating
# Epoch:  18 	batch:  3 	Validating
# Epoch:  18 	batch:  4 	Validating
# Epoch:  18 	batch:  5 	Validating
# Epoch:  18 	batch:  6 	Validating
# Epoch:  18 	batch:  7 	Validating
# Epoch:  18 	batch:  8 	Validating
# Epoch:  18 	batch:  9 	Validating
# Epoch:  18 	batch:  10 	Validating
# Epoch:  18 	batch:  11 	Validating
# Epoch:  19 	 batch:  0 	 Training
# Epoch:  19 	 batch:  1 	 Training
# Epoch:  19 	 batch:  2 	 Training
# Epoch:  19 	 batch:  3 	 Training
# Epoch:  19 	 batch:  4 	 Training
# Epoch:  19 	 batch:  5 	 Training
# Epoch:  19 	 batch:  6 	 Training
# Epoch:  19 	 batch:  7 	 Training
# Epoch:  19 	 batch:  8 	 Training
# Epoch:  19 	 batch:  9 	 Training
# Epoch:  19 	 batch:  10 	 Training
# Epoch:  19 	 batch:  11 	 Training
# Epoch:  19 	 batch:  12 	 Training
# Epoch:  19 	 batch:  13 	 Training
# Epoch:  19 	 batch:  14 	 Training
# Epoch:  19 	 batch:  15 	 Training
# Epoch:  19 	 batch:  16 	 Training
# Epoch:  19 	 batch:  17 	 Training
# Epoch:  19 	 batch:  18 	 Training
# Epoch:  19 	 batch:  19 	 Training
# Epoch:  19 	 batch:  20 	 Training
# Epoch:  19 	 batch:  21 	 Training
# Epoch:  19 	 batch:  22 	 Training
# Epoch:  19 	 batch:  23 	 Training
# Epoch:  19 	 batch:  24 	 Training
# Epoch:  19 	 batch:  25 	 Training
# Epoch:  19 	 batch:  26 	 Training
# Epoch:  19 	 batch:  27 	 Training
# Epoch:  19 	 batch:  28 	 Training
# Epoch:  19 	 batch:  29 	 Training
# Epoch:  19 	 batch:  30 	 Training
# Epoch:  19 	 batch:  31 	 Training
# Epoch:  19 	 batch:  32 	 Training
# Epoch:  19 	 batch:  33 	 Training
# Epoch:  19 	 batch:  34 	 Training
# Epoch:  19 	 batch:  35 	 Training
# Epoch:  19 	 batch:  36 	 Training
# Epoch:  19 	 batch:  37 	 Training
# Epoch:  19 	 batch:  38 	 Training
# Epoch:  19 	 batch:  39 	 Training
# Epoch:  19 	 batch:  40 	 Training
# Epoch:  19 	 batch:  41 	 Training
# Epoch:  19 	 batch:  42 	 Training
# Epoch:  19 	 batch:  43 	 Training
# Epoch:  19 	 batch:  44 	 Training
# Epoch:  19 	 batch:  45 	 Training
# Epoch:  19 	 batch:  46 	 Training
# Epoch:  19 	 batch:  47 	 Training
# Epoch:  19 	 batch:  48 	 Training
# Epoch:  19 	 batch:  49 	 Training
# Epoch:  19 	 batch:  50 	 Training
# Epoch:  19 	 batch:  51 	 Training
# Epoch:  19 	 batch:  52 	 Training
# Epoch:  19 	 batch:  53 	 Training
# Epoch:  19 	 batch:  54 	 Training
# Epoch:  19 	 batch:  55 	 Training
# Epoch:  19 	 batch:  56 	 Training
# Epoch:  19 	batch:  0 	Validating
# Epoch:  19 	batch:  1 	Validating
# Epoch:  19 	batch:  2 	Validating
# Epoch:  19 	batch:  3 	Validating
# Epoch:  19 	batch:  4 	Validating
# Epoch:  19 	batch:  5 	Validating
# Epoch:  19 	batch:  6 	Validating
# Epoch:  19 	batch:  7 	Validating
# Epoch:  19 	batch:  8 	Validating
# Epoch:  19 	batch:  9 	Validating
# Epoch:  19 	batch:  10 	Validating
# Epoch:  19 	batch:  11 	Validating
# Epoch:  20 	 batch:  0 	 Training
# Epoch:  20 	 batch:  1 	 Training
# Epoch:  20 	 batch:  2 	 Training
# Epoch:  20 	 batch:  3 	 Training
# Epoch:  20 	 batch:  4 	 Training
# Epoch:  20 	 batch:  5 	 Training
# Epoch:  20 	 batch:  6 	 Training
# Epoch:  20 	 batch:  7 	 Training
# Epoch:  20 	 batch:  8 	 Training
# Epoch:  20 	 batch:  9 	 Training
# Epoch:  20 	 batch:  10 	 Training
# Epoch:  20 	 batch:  11 	 Training
# Epoch:  20 	 batch:  12 	 Training
# Epoch:  20 	 batch:  13 	 Training
# Epoch:  20 	 batch:  14 	 Training
# Epoch:  20 	 batch:  15 	 Training
# Epoch:  20 	 batch:  16 	 Training
# Epoch:  20 	 batch:  17 	 Training
# Epoch:  20 	 batch:  18 	 Training
# Epoch:  20 	 batch:  19 	 Training
# Epoch:  20 	 batch:  20 	 Training
# Epoch:  20 	 batch:  21 	 Training
# ...
# Epoch:  93 	 batch:  23 	 Training
# Epoch:  93 	 batch:  24 	 Training
# Epoch:  93 	 batch:  25 	 Training
# Epoch:  93 	 batch:  26 	 Training
# Epoch:  93 	 batch:  27 	 Training
# Epoch:  93 	 batch:  28 	 Training
# Epoch:  93 	 batch:  29 	 Training
# Epoch:  93 	 batch:  30 	 Training
# Epoch:  93 	 batch:  31 	 Training
# Epoch:  93 	 batch:  32 	 Training
# Epoch:  93 	 batch:  33 	 Training
# Epoch:  93 	 batch:  34 	 Training
# Epoch:  93 	 batch:  35 	 Training
# Epoch:  93 	 batch:  36 	 Training
# Epoch:  93 	 batch:  37 	 Training
# Epoch:  93 	 batch:  38 	 Training
# Epoch:  93 	 batch:  39 	 Training
# Epoch:  93 	 batch:  40 	 Training
# Epoch:  93 	 batch:  41 	 Training
# Epoch:  93 	 batch:  42 	 Training
# Epoch:  93 	 batch:  43 	 Training
# Epoch:  93 	 batch:  44 	 Training
# Epoch:  93 	 batch:  45 	 Training
# Epoch:  93 	 batch:  46 	 Training
# Epoch:  93 	 batch:  47 	 Training
# Epoch:  93 	 batch:  48 	 Training
# Epoch:  93 	 batch:  49 	 Training
# Epoch:  93 	 batch:  50 	 Training
# Epoch:  93 	 batch:  51 	 Training
# Epoch:  93 	 batch:  52 	 Training
# Epoch:  93 	 batch:  53 	 Training
# Epoch:  93 	 batch:  54 	 Training
# Epoch:  93 	 batch:  55 	 Training
# Epoch:  93 	 batch:  56 	 Training
# Epoch:  93 	batch:  0 	Validating
# Epoch:  93 	batch:  1 	Validating
# Epoch:  93 	batch:  2 	Validating
# Epoch:  93 	batch:  3 	Validating
# Epoch:  93 	batch:  4 	Validating
# Epoch:  93 	batch:  5 	Validating
# Epoch:  93 	batch:  6 	Validating
# Epoch:  93 	batch:  7 	Validating
# Epoch:  93 	batch:  8 	Validating
# Epoch:  93 	batch:  9 	Validating
# Epoch:  93 	batch:  10 	Validating
# Epoch:  93 	batch:  11 	Validating
# Epoch:  94 	 batch:  0 	 Training
# Epoch:  94 	 batch:  1 	 Training
# Epoch:  94 	 batch:  2 	 Training
# Epoch:  94 	 batch:  3 	 Training
# Epoch:  94 	 batch:  4 	 Training
# Epoch:  94 	 batch:  5 	 Training
# Epoch:  94 	 batch:  6 	 Training
# Epoch:  94 	 batch:  7 	 Training
# Epoch:  94 	 batch:  8 	 Training
# Epoch:  94 	 batch:  9 	 Training
# Epoch:  94 	 batch:  10 	 Training
# Epoch:  94 	 batch:  11 	 Training
# Epoch:  94 	 batch:  12 	 Training
# Epoch:  94 	 batch:  13 	 Training
# Epoch:  94 	 batch:  14 	 Training
# Epoch:  94 	 batch:  15 	 Training
# Epoch:  94 	 batch:  16 	 Training
# Epoch:  94 	 batch:  17 	 Training
# Epoch:  94 	 batch:  18 	 Training
# Epoch:  94 	 batch:  19 	 Training
# Epoch:  94 	 batch:  20 	 Training
# Epoch:  94 	 batch:  21 	 Training
# Epoch:  94 	 batch:  22 	 Training
# Epoch:  94 	 batch:  23 	 Training
# Epoch:  94 	 batch:  24 	 Training
# Epoch:  94 	 batch:  25 	 Training
# Epoch:  94 	 batch:  26 	 Training
# Epoch:  94 	 batch:  27 	 Training
# Epoch:  94 	 batch:  28 	 Training
# Epoch:  94 	 batch:  29 	 Training
# Epoch:  94 	 batch:  30 	 Training
# Epoch:  94 	 batch:  31 	 Training
# Epoch:  94 	 batch:  32 	 Training
# Epoch:  94 	 batch:  33 	 Training
# Epoch:  94 	 batch:  34 	 Training
# Epoch:  94 	 batch:  35 	 Training
# Epoch:  94 	 batch:  36 	 Training
# Epoch:  94 	 batch:  37 	 Training
# Epoch:  94 	 batch:  38 	 Training
# Epoch:  94 	 batch:  39 	 Training
# Epoch:  94 	 batch:  40 	 Training
# Epoch:  94 	 batch:  41 	 Training
# Epoch:  94 	 batch:  42 	 Training
# Epoch:  94 	 batch:  43 	 Training
# Epoch:  94 	 batch:  44 	 Training
# Epoch:  94 	 batch:  45 	 Training
# Epoch:  94 	 batch:  46 	 Training
# Epoch:  94 	 batch:  47 	 Training
# Epoch:  94 	 batch:  48 	 Training
# Epoch:  94 	 batch:  49 	 Training
# Epoch:  94 	 batch:  50 	 Training
# Epoch:  94 	 batch:  51 	 Training
# Epoch:  94 	 batch:  52 	 Training
# Epoch:  94 	 batch:  53 	 Training
# Epoch:  94 	 batch:  54 	 Training
# Epoch:  94 	 batch:  55 	 Training
# Epoch:  94 	 batch:  56 	 Training
# Epoch:  94 	batch:  0 	Validating
# Epoch:  94 	batch:  1 	Validating
# Epoch:  94 	batch:  2 	Validating
# Epoch:  94 	batch:  3 	Validating
# Epoch:  94 	batch:  4 	Validating
# Epoch:  94 	batch:  5 	Validating
# Epoch:  94 	batch:  6 	Validating
# Epoch:  94 	batch:  7 	Validating
# Epoch:  94 	batch:  8 	Validating
# Epoch:  94 	batch:  9 	Validating
# Epoch:  94 	batch:  10 	Validating
# Epoch:  94 	batch:  11 	Validating
# Epoch:  95 	 batch:  0 	 Training
# Epoch:  95 	 batch:  1 	 Training
# Epoch:  95 	 batch:  2 	 Training
# Epoch:  95 	 batch:  3 	 Training
# Epoch:  95 	 batch:  4 	 Training
# Epoch:  95 	 batch:  5 	 Training
# Epoch:  95 	 batch:  6 	 Training
# Epoch:  95 	 batch:  7 	 Training
# Epoch:  95 	 batch:  8 	 Training
# Epoch:  95 	 batch:  9 	 Training
# Epoch:  95 	 batch:  10 	 Training
# Epoch:  95 	 batch:  11 	 Training
# Epoch:  95 	 batch:  12 	 Training
# Epoch:  95 	 batch:  13 	 Training
# Epoch:  95 	 batch:  14 	 Training
# Epoch:  95 	 batch:  15 	 Training
# Epoch:  95 	 batch:  16 	 Training
# Epoch:  95 	 batch:  17 	 Training
# Epoch:  95 	 batch:  18 	 Training
# Epoch:  95 	 batch:  19 	 Training
# Epoch:  95 	 batch:  20 	 Training
# Epoch:  95 	 batch:  21 	 Training
# Epoch:  95 	 batch:  22 	 Training
# Epoch:  95 	 batch:  23 	 Training
# Epoch:  95 	 batch:  24 	 Training
# Epoch:  95 	 batch:  25 	 Training
# Epoch:  95 	 batch:  26 	 Training
# Epoch:  95 	 batch:  27 	 Training
# Epoch:  95 	 batch:  28 	 Training
# Epoch:  95 	 batch:  29 	 Training
# Epoch:  95 	 batch:  30 	 Training
# Epoch:  95 	 batch:  31 	 Training
# Epoch:  95 	 batch:  32 	 Training
# Epoch:  95 	 batch:  33 	 Training
# Epoch:  95 	 batch:  34 	 Training
# Epoch:  95 	 batch:  35 	 Training
# Epoch:  95 	 batch:  36 	 Training
# Epoch:  95 	 batch:  37 	 Training
# Epoch:  95 	 batch:  38 	 Training
# Epoch:  95 	 batch:  39 	 Training
# Epoch:  95 	 batch:  40 	 Training
# Epoch:  95 	 batch:  41 	 Training
# Epoch:  95 	 batch:  42 	 Training
# Epoch:  95 	 batch:  43 	 Training
# Epoch:  95 	 batch:  44 	 Training
# Epoch:  95 	 batch:  45 	 Training
# Epoch:  95 	 batch:  46 	 Training
# Epoch:  95 	 batch:  47 	 Training
# Epoch:  95 	 batch:  48 	 Training
# Epoch:  95 	 batch:  49 	 Training
# Epoch:  95 	 batch:  50 	 Training
# Epoch:  95 	 batch:  51 	 Training
# Epoch:  95 	 batch:  52 	 Training
# Epoch:  95 	 batch:  53 	 Training
# Epoch:  95 	 batch:  54 	 Training
# Epoch:  95 	 batch:  55 	 Training
# Epoch:  95 	 batch:  56 	 Training
# Epoch:  95 	batch:  0 	Validating
# Epoch:  95 	batch:  1 	Validating
# Epoch:  95 	batch:  2 	Validating
# Epoch:  95 	batch:  3 	Validating
# Epoch:  95 	batch:  4 	Validating
# Epoch:  95 	batch:  5 	Validating
# Epoch:  95 	batch:  6 	Validating
# Epoch:  95 	batch:  7 	Validating
# Epoch:  95 	batch:  8 	Validating
# Epoch:  95 	batch:  9 	Validating
# Epoch:  95 	batch:  10 	Validating
# Epoch:  95 	batch:  11 	Validating
# Epoch:  96 	 batch:  0 	 Training
# Epoch:  96 	 batch:  1 	 Training
# Epoch:  96 	 batch:  2 	 Training
# Epoch:  96 	 batch:  3 	 Training
# Epoch:  96 	 batch:  4 	 Training
# Epoch:  96 	 batch:  5 	 Training
# Epoch:  96 	 batch:  6 	 Training
# Epoch:  96 	 batch:  7 	 Training
# Epoch:  96 	 batch:  8 	 Training
# Epoch:  96 	 batch:  9 	 Training
# Epoch:  96 	 batch:  10 	 Training
# Epoch:  96 	 batch:  11 	 Training
# Epoch:  96 	 batch:  12 	 Training
# Epoch:  96 	 batch:  13 	 Training
# Epoch:  96 	 batch:  14 	 Training
# Epoch:  96 	 batch:  15 	 Training
# Epoch:  96 	 batch:  16 	 Training
# Epoch:  96 	 batch:  17 	 Training
# Epoch:  96 	 batch:  18 	 Training
# Epoch:  96 	 batch:  19 	 Training
# Epoch:  96 	 batch:  20 	 Training
# Epoch:  96 	 batch:  21 	 Training
# Epoch:  96 	 batch:  22 	 Training
# Epoch:  96 	 batch:  23 	 Training
# Epoch:  96 	 batch:  24 	 Training
# Epoch:  96 	 batch:  25 	 Training
# Epoch:  96 	 batch:  26 	 Training
# Epoch:  96 	 batch:  27 	 Training
# Epoch:  96 	 batch:  28 	 Training
# Epoch:  96 	 batch:  29 	 Training
# Epoch:  96 	 batch:  30 	 Training
# Epoch:  96 	 batch:  31 	 Training
# Epoch:  96 	 batch:  32 	 Training
# Epoch:  96 	 batch:  33 	 Training
# Epoch:  96 	 batch:  34 	 Training
# Epoch:  96 	 batch:  35 	 Training
# Epoch:  96 	 batch:  36 	 Training
# Epoch:  96 	 batch:  37 	 Training
# Epoch:  96 	 batch:  38 	 Training
# Epoch:  96 	 batch:  39 	 Training
# Epoch:  96 	 batch:  40 	 Training
# Epoch:  96 	 batch:  41 	 Training
# Epoch:  96 	 batch:  42 	 Training
# Epoch:  96 	 batch:  43 	 Training
# Epoch:  96 	 batch:  44 	 Training
# Epoch:  96 	 batch:  45 	 Training
# Epoch:  96 	 batch:  46 	 Training
# Epoch:  96 	 batch:  47 	 Training
# Epoch:  96 	 batch:  48 	 Training
# Epoch:  96 	 batch:  49 	 Training
# Epoch:  96 	 batch:  50 	 Training
# Epoch:  96 	 batch:  51 	 Training
# Epoch:  96 	 batch:  52 	 Training
# Epoch:  96 	 batch:  53 	 Training
# Epoch:  96 	 batch:  54 	 Training
# Epoch:  96 	 batch:  55 	 Training
# Epoch:  96 	 batch:  56 	 Training
# Epoch:  96 	batch:  0 	Validating
# Epoch:  96 	batch:  1 	Validating
# Epoch:  96 	batch:  2 	Validating
# Epoch:  96 	batch:  3 	Validating
# Epoch:  96 	batch:  4 	Validating
# Epoch:  96 	batch:  5 	Validating
# Epoch:  96 	batch:  6 	Validating
# Epoch:  96 	batch:  7 	Validating
# Epoch:  96 	batch:  8 	Validating
# Epoch:  96 	batch:  9 	Validating
# Epoch:  96 	batch:  10 	Validating
# Epoch:  96 	batch:  11 	Validating
# Epoch:  97 	 batch:  0 	 Training
# Epoch:  97 	 batch:  1 	 Training
# Epoch:  97 	 batch:  2 	 Training
# Epoch:  97 	 batch:  3 	 Training
# Epoch:  97 	 batch:  4 	 Training
# Epoch:  97 	 batch:  5 	 Training
# Epoch:  97 	 batch:  6 	 Training
# Epoch:  97 	 batch:  7 	 Training
# Epoch:  97 	 batch:  8 	 Training
# Epoch:  97 	 batch:  9 	 Training
# Epoch:  97 	 batch:  10 	 Training
# Epoch:  97 	 batch:  11 	 Training
# Epoch:  97 	 batch:  12 	 Training
# Epoch:  97 	 batch:  13 	 Training
# Epoch:  97 	 batch:  14 	 Training
# Epoch:  97 	 batch:  15 	 Training
# Epoch:  97 	 batch:  16 	 Training
# Epoch:  97 	 batch:  17 	 Training
# Epoch:  97 	 batch:  18 	 Training
# Epoch:  97 	 batch:  19 	 Training
# Epoch:  97 	 batch:  20 	 Training
# Epoch:  97 	 batch:  21 	 Training
# Epoch:  97 	 batch:  22 	 Training
# Epoch:  97 	 batch:  23 	 Training
# Epoch:  97 	 batch:  24 	 Training
# Epoch:  97 	 batch:  25 	 Training
# Epoch:  97 	 batch:  26 	 Training
# Epoch:  97 	 batch:  27 	 Training
# Epoch:  97 	 batch:  28 	 Training
# Epoch:  97 	 batch:  29 	 Training
# Epoch:  97 	 batch:  30 	 Training
# Epoch:  97 	 batch:  31 	 Training
# Epoch:  97 	 batch:  32 	 Training
# Epoch:  97 	 batch:  33 	 Training
# Epoch:  97 	 batch:  34 	 Training
# Epoch:  97 	 batch:  35 	 Training
# Epoch:  97 	 batch:  36 	 Training
# Epoch:  97 	 batch:  37 	 Training
# Epoch:  97 	 batch:  38 	 Training
# Epoch:  97 	 batch:  39 	 Training
# Epoch:  97 	 batch:  40 	 Training
# Epoch:  97 	 batch:  41 	 Training
# Epoch:  97 	 batch:  42 	 Training
# Epoch:  97 	 batch:  43 	 Training
# Epoch:  97 	 batch:  44 	 Training
# Epoch:  97 	 batch:  45 	 Training
# Epoch:  97 	 batch:  46 	 Training
# Epoch:  97 	 batch:  47 	 Training
# Epoch:  97 	 batch:  48 	 Training
# Epoch:  97 	 batch:  49 	 Training
# Epoch:  97 	 batch:  50 	 Training
# Epoch:  97 	 batch:  51 	 Training
# Epoch:  97 	 batch:  52 	 Training
# Epoch:  97 	 batch:  53 	 Training
# Epoch:  97 	 batch:  54 	 Training
# Epoch:  97 	 batch:  55 	 Training
# Epoch:  97 	 batch:  56 	 Training
# Epoch:  97 	batch:  0 	Validating
# Epoch:  97 	batch:  1 	Validating
# Epoch:  97 	batch:  2 	Validating
# Epoch:  97 	batch:  3 	Validating
# Epoch:  97 	batch:  4 	Validating
# Epoch:  97 	batch:  5 	Validating
# Epoch:  97 	batch:  6 	Validating
# Epoch:  97 	batch:  7 	Validating
# Epoch:  97 	batch:  8 	Validating
# Epoch:  97 	batch:  9 	Validating
# Epoch:  97 	batch:  10 	Validating
# Epoch:  97 	batch:  11 	Validating
# Epoch:  98 	 batch:  0 	 Training
# Epoch:  98 	 batch:  1 	 Training
# Epoch:  98 	 batch:  2 	 Training
# Epoch:  98 	 batch:  3 	 Training
# Epoch:  98 	 batch:  4 	 Training
# Epoch:  98 	 batch:  5 	 Training
# Epoch:  98 	 batch:  6 	 Training
# Epoch:  98 	 batch:  7 	 Training
# Epoch:  98 	 batch:  8 	 Training
# Epoch:  98 	 batch:  9 	 Training
# Epoch:  98 	 batch:  10 	 Training
# Epoch:  98 	 batch:  11 	 Training
# Epoch:  98 	 batch:  12 	 Training
# Epoch:  98 	 batch:  13 	 Training
# Epoch:  98 	 batch:  14 	 Training
# Epoch:  98 	 batch:  15 	 Training
# Epoch:  98 	 batch:  16 	 Training
# Epoch:  98 	 batch:  17 	 Training
# Epoch:  98 	 batch:  18 	 Training
# Epoch:  98 	 batch:  19 	 Training
# Epoch:  98 	 batch:  20 	 Training
# Epoch:  98 	 batch:  21 	 Training
# Epoch:  98 	 batch:  22 	 Training
# Epoch:  98 	 batch:  23 	 Training
# Epoch:  98 	 batch:  24 	 Training
# Epoch:  98 	 batch:  25 	 Training
# Epoch:  98 	 batch:  26 	 Training
# Epoch:  98 	 batch:  27 	 Training
# Epoch:  98 	 batch:  28 	 Training
# Epoch:  98 	 batch:  29 	 Training
# Epoch:  98 	 batch:  30 	 Training
# Epoch:  98 	 batch:  31 	 Training
# Epoch:  98 	 batch:  32 	 Training
# Epoch:  98 	 batch:  33 	 Training
# Epoch:  98 	 batch:  34 	 Training
# Epoch:  98 	 batch:  35 	 Training
# Epoch:  98 	 batch:  36 	 Training
# Epoch:  98 	 batch:  37 	 Training
# Epoch:  98 	 batch:  38 	 Training
# Epoch:  98 	 batch:  39 	 Training
# Epoch:  98 	 batch:  40 	 Training
# Epoch:  98 	 batch:  41 	 Training
# Epoch:  98 	 batch:  42 	 Training
# Epoch:  98 	 batch:  43 	 Training
# Epoch:  98 	 batch:  44 	 Training
# Epoch:  98 	 batch:  45 	 Training
# Epoch:  98 	 batch:  46 	 Training
# Epoch:  98 	 batch:  47 	 Training
# Epoch:  98 	 batch:  48 	 Training
# Epoch:  98 	 batch:  49 	 Training
# Epoch:  98 	 batch:  50 	 Training
# Epoch:  98 	 batch:  51 	 Training
# Epoch:  98 	 batch:  52 	 Training
# Epoch:  98 	 batch:  53 	 Training
# Epoch:  98 	 batch:  54 	 Training
# Epoch:  98 	 batch:  55 	 Training
# Epoch:  98 	 batch:  56 	 Training
# Epoch:  98 	batch:  0 	Validating
# Epoch:  98 	batch:  1 	Validating
# Epoch:  98 	batch:  2 	Validating
# Epoch:  98 	batch:  3 	Validating
# Epoch:  98 	batch:  4 	Validating
# Epoch:  98 	batch:  5 	Validating
# Epoch:  98 	batch:  6 	Validating
# Epoch:  98 	batch:  7 	Validating
# Epoch:  98 	batch:  8 	Validating
# Epoch:  98 	batch:  9 	Validating
# Epoch:  98 	batch:  10 	Validating
# Epoch:  98 	batch:  11 	Validating
# Epoch:  99 	 batch:  0 	 Training
# Epoch:  99 	 batch:  1 	 Training
# Epoch:  99 	 batch:  2 	 Training
# Epoch:  99 	 batch:  3 	 Training
# Epoch:  99 	 batch:  4 	 Training
# Epoch:  99 	 batch:  5 	 Training
# Epoch:  99 	 batch:  6 	 Training
# Epoch:  99 	 batch:  7 	 Training
# Epoch:  99 	 batch:  8 	 Training
# Epoch:  99 	 batch:  9 	 Training
# Epoch:  99 	 batch:  10 	 Training
# Epoch:  99 	 batch:  11 	 Training
# Epoch:  99 	 batch:  12 	 Training
# Epoch:  99 	 batch:  13 	 Training
# Epoch:  99 	 batch:  14 	 Training
# Epoch:  99 	 batch:  15 	 Training
# Epoch:  99 	 batch:  16 	 Training
# Epoch:  99 	 batch:  17 	 Training
# Epoch:  99 	 batch:  18 	 Training
# Epoch:  99 	 batch:  19 	 Training
# Epoch:  99 	 batch:  20 	 Training
# Epoch:  99 	 batch:  21 	 Training
# Epoch:  99 	 batch:  22 	 Training
# Epoch:  99 	 batch:  23 	 Training
# Epoch:  99 	 batch:  24 	 Training
# Epoch:  99 	 batch:  25 	 Training
# Epoch:  99 	 batch:  26 	 Training
# Epoch:  99 	 batch:  27 	 Training
# Epoch:  99 	 batch:  28 	 Training
# Epoch:  99 	 batch:  29 	 Training
# Epoch:  99 	 batch:  30 	 Training
# Epoch:  99 	 batch:  31 	 Training
# Epoch:  99 	 batch:  32 	 Training
# Epoch:  99 	 batch:  33 	 Training
# Epoch:  99 	 batch:  34 	 Training
# Epoch:  99 	 batch:  35 	 Training
# Epoch:  99 	 batch:  36 	 Training
# Epoch:  99 	 batch:  37 	 Training
# Epoch:  99 	 batch:  38 	 Training
# Epoch:  99 	 batch:  39 	 Training
# Epoch:  99 	 batch:  40 	 Training
# Epoch:  99 	 batch:  41 	 Training
# Epoch:  99 	 batch:  42 	 Training
# Epoch:  99 	 batch:  43 	 Training
# Epoch:  99 	 batch:  44 	 Training
# Epoch:  99 	 batch:  45 	 Training
# Epoch:  99 	 batch:  46 	 Training
# Epoch:  99 	 batch:  47 	 Training
# Epoch:  99 	 batch:  48 	 Training
# Epoch:  99 	 batch:  49 	 Training
# Epoch:  99 	 batch:  50 	 Training
# Epoch:  99 	 batch:  51 	 Training
# Epoch:  99 	 batch:  52 	 Training
# Epoch:  99 	 batch:  53 	 Training
# Epoch:  99 	 batch:  54 	 Training
# Epoch:  99 	 batch:  55 	 Training
# Epoch:  99 	 batch:  56 	 Training
# Epoch:  99 	batch:  0 	Validating
# Epoch:  99 	batch:  1 	Validating
# Epoch:  99 	batch:  2 	Validating
# Epoch:  99 	batch:  3 	Validating
# Epoch:  99 	batch:  4 	Validating
# Epoch:  99 	batch:  5 	Validating
# Epoch:  99 	batch:  6 	Validating
# Epoch:  99 	batch:  7 	Validating
# Epoch:  99 	batch:  8 	Validating
# Epoch:  99 	batch:  9 	Validating
# Epoch:  99 	batch:  10 	Validating
# Epoch:  99 	batch:  11 	Validating

# %%
pred_validation
# Out:
# array([[9.99999967e-01, 2.36787177e-08],
#        [2.72457334e-01, 7.35755569e-01],
#        [1.00000000e+00, 5.23304346e-20],
#        ...,
#        [9.99995283e-01, 4.22680540e-06],
#        [1.00000000e+00, 3.65954178e-19],
#        [1.00000000e+00, 1.00489219e-15]])

# %%
pred_test = []
for i in range(batch_test):
    X_batch = fps_test[i*batch_size:(i+1)*batch_size]
    Y_batch = labels_test[i*batch_size:(i+1)*batch_size]
    _Y, _loss = sess.run([Y_pred, loss], feed_dict = {X: X_batch, Y: Y_batch, is_training: False})
    print("Batch: ", i, "\t Testing")
    pred_test.append(_Y)
pred_test = np.concatenate(pred_test, axis=0)
# Out:
# Batch:  0 	 Testing
# Batch:  1 	 Testing
# Batch:  2 	 Testing
# Batch:  3 	 Testing
# Batch:  4 	 Testing
# Batch:  5 	 Testing
# Batch:  6 	 Testing
# Batch:  7 	 Testing
# Batch:  8 	 Testing
# Batch:  9 	 Testing
# Batch:  10 	 Testing
# Batch:  11 	 Testing

# %%
labels_test_result = labels[num_total-num_test:num_total-num_test+len(pred_test)]
labels_pred_result = np.zeros(len(pred_test))
for i in range(len(pred_test)):
    labels_pred_result[i] = 0 if pred_test[i][0]>pred_test[i][1] else 1

print(labels_test_result.shape, labels_pred_result.shape)
    
accuracy = accuracy_score(labels_test_result, labels_pred_result)
auc_roc = roc_auc_score(labels_test_result, labels_pred_result)

accuracy, auc_roc
# Out:
# (1200,) (1200,)
# (0.9458333333333333, 0.8277234238037297)
